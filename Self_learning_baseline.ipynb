# %%
import os
import json
import torch
import torchvision.models as models
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F
from torch import nn, optim
from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder
from torchvision import datasets, transforms, models # add models to the list
from sklearn.metrics import classification_report
from torch.utils.data import Dataset
from PIL import Image
import time
from tqdm import tqdm
import numpy as np
import random
from torchvision.models import resnet18, ResNet18_Weights
from torch.optim.lr_scheduler import ReduceLROnPlateau

# %%
PROJECT_ROOT = os.getcwd()

# %%
root = os.path.join(PROJECT_ROOT, 'brain tumor data')

# %%
test_path = root+'/test/'
train_path = root+'/train/'
validation_path = root + '/valid/'

# %%
train_img_dir = root + '/train'
valid_img_dir = root + '/valid'

# %%
fixed_annotation_file = root + '/train/fixed_annotations.json'
image_dir = train_img_dir

# %%
class SimCLRDataset(Dataset):
    def __init__(self, fixed_annotation_file, image_dir, transform=None):
        with open(fixed_annotation_file, 'r') as f:
            coco_data = json.load(f)
        
        # mapping image_id to category_id
        image_id_to_label = {ann['image_id']: ann['category_id'] for ann in coco_data['annotations']}

        self.samples = []
        for img in coco_data['images']:
            file_name = img['file_name']
            img_id = img['id']
            label = image_id_to_label.get(img_id) # use get(img_id) is to look up the category_id(label) for the image using its ID

            if label is not None:
                image_path = os.path.join(image_dir, file_name)
                self.samples.append((image_path, label-1))
            
        self.transform = transform
    def __len__(self):
        return len(self.samples)
    def __getitem__(self, idx):
        image_path, label = self.samples[idx]
        image = Image.open(image_path).convert('RGB')
        xi, xj = self.transform(image)
        return xi, xj

# %%
# transformation for SimCLR
from torchvision import transforms
class TwoCropTransform:
    def __init__(self,base_transform):
        self.base_transform = base_transform
    def __call__(self, x):
        return self.base_transform(x), self.base_transform(x)

simclr_transform = TwoCropTransform(transforms.Compose([
        transforms.RandomAffine(degrees=0, shear=5, scale=(0.95,1.05)),
        transforms.RandomRotation(3),      
        transforms.RandomHorizontalFlip(p=0.5),  # reverse 50% of images
        transforms.RandomVerticalFlip(p=0.3),  # reverse 30% of images
        transforms.GaussianBlur(3, sigma=(0.1, 1.0)),
        transforms.Resize(224),             # resize shortest side to 224 pixels
        transforms.CenterCrop(224),         # crop longest side to 224 pixels at center
        transforms.ToTensor(),
        transforms.Normalize([0.5],[0.5])
    ]))

# SimCLR model
class SimCLR(nn.Module):
    def __init__(self, projection_dim=128):
        super().__init__()
        self.encoder = models.resnet18(weights=ResNet18_Weights.DEFAULT) 
        self.encoder.fc = nn.Identity()
        in_features = 512
        self.projector = nn.Sequential(
            nn.Linear(in_features, 512),
            nn.ReLU(),
            nn.Linear(512, projection_dim)
        )
    def forward(self, x):
        h = self.encoder(x)
        z = self.projector(h)
        return z

# %%
class NTXentLoss(nn.Module):
    def __init__(self, temperature = 0.3):
        super(NTXentLoss, self).__init__()
        self.temperature = temperature
        self.cos_sim = nn.CosineSimilarity(dim=2)
        
    def forward(self, zis, zjs):
        batch_size = zis.size(0)
        reps = torch.cat([zis, zjs], dim=0)
        sim_matrix = self.cos_sim(reps.unsqueeze(1), reps.unsqueeze(0))
        
        labels = torch.cat([torch.arange(batch_size) for _ in range(2)], dim=0)
        labels = (labels.unsqueeze(0) == labels.unsqueeze(1)).float().to(zis.device)

        mask = torch.eye(labels.shape[0],dtype=torch.bool).to(zis.device)
        labels = labels[~mask].view(labels.shape[0], -1)
        sim_matrix = sim_matrix[~mask].view(sim_matrix.shape[0], -1)

        positives = sim_matrix[labels.bool()].view(labels.shape[0], -1)
        negatives = sim_matrix[~labels.bool()].view(sim_matrix.shape[0], -1)

        logits = torch.cat([positives, negatives], dim=1)
        labels = torch.zeros(logits.shape[0],dtype=torch.long).to(zis.device)
        return F.cross_entropy(logits / self.temperature, labels)

# %%
import torch
import torch.nn as nn
from torchvision import models
from torchvision.models import resnet18, ResNet18_Weights
from torch.optim.lr_scheduler import ReduceLROnPlateau
import time
import random
import numpy as np

def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
#entry point
def run_simclr_training(train_ann, train_img_dir, batch_size, epochs=100, patience=6, min_delta=1e-4):
    set_seed(42)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    dataset = SimCLRDataset(train_ann, train_img_dir, simclr_transform)
    dataloader = DataLoader(dataset, batch_size=128, shuffle=True, drop_last=True, num_workers=4)

    model = SimCLR().to(device)
    
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-4, weight_decay = 1e-5)
    criterion = NTXentLoss(temperature=0.3)
    scheduler = ReduceLROnPlateau(optimizer, mode = 'min', factor =0.5, patience=3, threshold=0.001)
    
    #scheduler = CosineAnnealingLR(optimizer, T_max =100, eta_min=1e-6)
# early stopping
    best_loss = float('inf')
    patience_counter = 0
    start_time = time.time()

    for epoch in range(epochs):
        total_loss = 0
        for xi, xj in dataloader:
            xi, xj = xi.to(device), xj.to(device)
            zi = model(xi)
            zj = model(xj)

            loss = criterion(zi, zj)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            total_loss += loss.item()
        avg_loss = total_loss / len(dataloader)
        print(f"SimCLR pretraining - Epoch [{epoch+1}/{epochs}] Loss: {avg_loss:.4f}")

        if avg_loss < best_loss - min_delta:
            best_loss = avg_loss
            patience_counter = 0
        else:
            patience_counter += 1
        
        # stop training if patience limit is exceed
        if patience_counter >= patience:
            print(f"Early stopping triggered at epoch {epoch+1}. No improvement for {patience} epoches.")
            break
        #scheduler.step(avg_loss)
 
    torch.save(model.encoder.state_dict(), 'simclr_encoder.pth')
    duration = time.time() - start_time
    print(f'\nDuration: {duration:.0f} seconds') # Print time elapsed

    return model.encoder
   
# define the linear evaluation model
class LinearClassifier(nn.Module):
    def __init__(self, encoder, feature_dim, num_classes):
        super(LinearClassifier, self).__init__()
        self.encoder = encoder
        for param in self.encoder.parameters():
            param.requires_grad = False
        self.classifier = nn.Linear(feature_dim, num_classes)
    def forward(self, x):
        with torch.no_grad():
            h = self.encoder(x)
        return self.classifier(h)

# %%
train_transform = transforms.Compose([
        transforms.RandomAffine(degrees=0, shear=5, scale=(0.95,1.05)),
        transforms.RandomRotation(3),      
        transforms.RandomHorizontalFlip(p=0.5),  # reverse 50% of images
        transforms.RandomVerticalFlip(p=0.3),  # reverse 30% of images
        transforms.GaussianBlur(3, sigma=(0.1, 1.0)),
        transforms.Resize(224),             # resize shortest side to 224 pixels
        transforms.CenterCrop(224),         # crop longest side to 224 pixels at center
        transforms.ToTensor(),
        transforms.Normalize([0.5],[0.5])
    ])


valid_transform = transforms.Compose([
        transforms.Resize(224),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.5],[0.5])
    ])

# %%
class TumorDataset(Dataset):
    def __init__(self, fixed_annotation_file, image_dir, transform=None):
        with open(fixed_annotation_file, 'r') as f:
            coco_data = json.load(f)
        
        # mapping image_id to category_id
        image_id_to_label = {ann['image_id']: ann['category_id'] for ann in coco_data['annotations']}

        self.samples = []
        for img in coco_data['images']:
            file_name = img['file_name']
            img_id = img['id']
            label = image_id_to_label.get(img_id) # use get(img_id) is to look up the category_id(label) for the image using its ID

            if label is not None:
                image_path = os.path.join(image_dir, file_name)
                self.samples.append((image_path, label-1))
            
        self.transform = transform
    def __len__(self):
        return len(self.samples)
    def __getitem__(self, idx):
        image_path, label = self.samples[idx]
        image = Image.open(image_path).convert('RGB')
        if self.transform:
            image = self.transform(image)
        return image, label

# %%
# check if GPU is available 
torch.cuda.is_available()
# Out:
# True

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
device
# Out:
# device(type='cuda')

# %%
# SimCLR pretraining
encoder = run_simclr_training(
    train_ann=root + '/train/fixed_annotations.json',
    train_img_dir=train_img_dir,
    batch_size=128,
    epochs=100,
    patience=6,
    min_delta=1e-4
    )
# Out:
# SimCLR pretraining - Epoch [1/100] Loss: 3.8206
# SimCLR pretraining - Epoch [2/100] Loss: 3.1313
# SimCLR pretraining - Epoch [3/100] Loss: 2.9078
# SimCLR pretraining - Epoch [4/100] Loss: 2.8023
# SimCLR pretraining - Epoch [5/100] Loss: 2.7289
# SimCLR pretraining - Epoch [6/100] Loss: 2.6792
# SimCLR pretraining - Epoch [7/100] Loss: 2.6496
# SimCLR pretraining - Epoch [8/100] Loss: 2.6210
# SimCLR pretraining - Epoch [9/100] Loss: 2.5975
# SimCLR pretraining - Epoch [10/100] Loss: 2.5779
# SimCLR pretraining - Epoch [11/100] Loss: 2.5603
# SimCLR pretraining - Epoch [12/100] Loss: 2.5486
# SimCLR pretraining - Epoch [13/100] Loss: 2.5348
# SimCLR pretraining - Epoch [14/100] Loss: 2.5245
# SimCLR pretraining - Epoch [15/100] Loss: 2.5166
# SimCLR pretraining - Epoch [16/100] Loss: 2.5060
# SimCLR pretraining - Epoch [17/100] Loss: 2.4987
# SimCLR pretraining - Epoch [18/100] Loss: 2.4925
# SimCLR pretraining - Epoch [19/100] Loss: 2.4875
# SimCLR pretraining - Epoch [20/100] Loss: 2.4801
# SimCLR pretraining - Epoch [21/100] Loss: 2.4786
# SimCLR pretraining - Epoch [22/100] Loss: 2.4720
# SimCLR pretraining - Epoch [23/100] Loss: 2.4644
# SimCLR pretraining - Epoch [24/100] Loss: 2.4622
# SimCLR pretraining - Epoch [25/100] Loss: 2.4640
# SimCLR pretraining - Epoch [26/100] Loss: 2.4580
# SimCLR pretraining - Epoch [27/100] Loss: 2.4571
# SimCLR pretraining - Epoch [28/100] Loss: 2.4541
# SimCLR pretraining - Epoch [29/100] Loss: 2.4466
# SimCLR pretraining - Epoch [30/100] Loss: 2.4450
# SimCLR pretraining - Epoch [31/100] Loss: 2.4441
# SimCLR pretraining - Epoch [32/100] Loss: 2.4418
# SimCLR pretraining - Epoch [33/100] Loss: 2.4359
# SimCLR pretraining - Epoch [34/100] Loss: 2.4387
# SimCLR pretraining - Epoch [35/100] Loss: 2.4326
# SimCLR pretraining - Epoch [36/100] Loss: 2.4319
# SimCLR pretraining - Epoch [37/100] Loss: 2.4340
# SimCLR pretraining - Epoch [38/100] Loss: 2.4283
# SimCLR pretraining - Epoch [39/100] Loss: 2.4309
# SimCLR pretraining - Epoch [40/100] Loss: 2.4268
# SimCLR pretraining - Epoch [41/100] Loss: 2.4255
# SimCLR pretraining - Epoch [42/100] Loss: 2.4201
# SimCLR pretraining - Epoch [43/100] Loss: 2.4195
# SimCLR pretraining - Epoch [44/100] Loss: 2.4237
# SimCLR pretraining - Epoch [45/100] Loss: 2.4210
# SimCLR pretraining - Epoch [46/100] Loss: 2.4162
# SimCLR pretraining - Epoch [47/100] Loss: 2.4126
# SimCLR pretraining - Epoch [48/100] Loss: 2.4177
# SimCLR pretraining - Epoch [49/100] Loss: 2.4143
# SimCLR pretraining - Epoch [50/100] Loss: 2.4120
# SimCLR pretraining - Epoch [51/100] Loss: 2.4093
# SimCLR pretraining - Epoch [52/100] Loss: 2.4111
# SimCLR pretraining - Epoch [53/100] Loss: 2.4093
# SimCLR pretraining - Epoch [54/100] Loss: 2.4091
# SimCLR pretraining - Epoch [55/100] Loss: 2.4078
# SimCLR pretraining - Epoch [56/100] Loss: 2.4039
# SimCLR pretraining - Epoch [57/100] Loss: 2.4073
# SimCLR pretraining - Epoch [58/100] Loss: 2.4065
# SimCLR pretraining - Epoch [59/100] Loss: 2.4047
# SimCLR pretraining - Epoch [60/100] Loss: 2.4024
# SimCLR pretraining - Epoch [61/100] Loss: 2.4006
# SimCLR pretraining - Epoch [62/100] Loss: 2.4046
# SimCLR pretraining - Epoch [63/100] Loss: 2.4005
# SimCLR pretraining - Epoch [64/100] Loss: 2.4031
# SimCLR pretraining - Epoch [65/100] Loss: 2.4004
# SimCLR pretraining - Epoch [66/100] Loss: 2.4011
# SimCLR pretraining - Epoch [67/100] Loss: 2.3998
# SimCLR pretraining - Epoch [68/100] Loss: 2.3990
# SimCLR pretraining - Epoch [69/100] Loss: 2.3961
# SimCLR pretraining - Epoch [70/100] Loss: 2.3985
# SimCLR pretraining - Epoch [71/100] Loss: 2.3973
# SimCLR pretraining - Epoch [72/100] Loss: 2.3960
# SimCLR pretraining - Epoch [73/100] Loss: 2.3961
# SimCLR pretraining - Epoch [74/100] Loss: 2.3927
# SimCLR pretraining - Epoch [75/100] Loss: 2.3938
# SimCLR pretraining - Epoch [76/100] Loss: 2.3929
# SimCLR pretraining - Epoch [77/100] Loss: 2.3933
# SimCLR pretraining - Epoch [78/100] Loss: 2.3906
# SimCLR pretraining - Epoch [79/100] Loss: 2.3923
# SimCLR pretraining - Epoch [80/100] Loss: 2.3909
# SimCLR pretraining - Epoch [81/100] Loss: 2.3924
# SimCLR pretraining - Epoch [82/100] Loss: 2.3919
# SimCLR pretraining - Epoch [83/100] Loss: 2.3914
# SimCLR pretraining - Epoch [84/100] Loss: 2.3942
# Early stopping triggered at epoch 84. No improvement for 6 epoches.
#
# Duration: 1383 seconds

# %%
encoder.eval()
encoder=encoder.to(device)

# %%
# Load datasets for linear evaluation
train_data = TumorDataset(
    fixed_annotation_file=root + '/train/fixed_annotations.json',
    image_dir=train_img_dir,
    transform=train_transform
)
valid_data = TumorDataset(
    fixed_annotation_file=root + '/valid/_annotations.coco.json',
    image_dir=valid_img_dir,
    transform=valid_transform
)

train_loader = DataLoader(train_data, batch_size=32, shuffle=True)
valid_loader = DataLoader(valid_data, batch_size=32, shuffle=True)

# %%
# start to load pre-trained ResNet18 model and fine-tune
import os
import time
from tqdm import tqdm
import numpy as np
import random
import shutil

save_dir_simclr = os.path.join(PROJECT_ROOT, 'base_simclr_new')
os.makedirs(save_dir_simclr,exist_ok = True)
num_runs = 3
train_accuracies_all = []
valid_accuracies_all = []
train_losses_all = []
valid_losses_all = []

all_train_acc = []
all_val_acc =[]
all_train_loss = []
all_val_loss =[]
# track the best val loss of each run 
best_val_losses_all = []



for run in range(num_runs):
    print(f"\n===== Run {run+1} =====\n")
    torch.manual_seed(42 + run)
    torch.cuda.manual_seed(42 + run)
    np.random.seed(42 + run)
    random.seed(42 + run)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

    train_loader = DataLoader(train_data, batch_size = 32, shuffle=True)
    valid_loader = DataLoader(valid_data, batch_size = 32, shuffle=True)

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    encoder.eval()
    model = LinearClassifier(encoder, feature_dim=512, num_classes=2).to(device)
    criterion = nn.CrossEntropyLoss(label_smoothing=0.05)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-4, weight_decay=1e-5)
    scheduler = ReduceLROnPlateau(optimizer, mode = 'min', factor =0.5, patience=3, threshold=0.001)
    best_val_acc = 0
    best_model_path = os.path.join(save_dir_simclr, f"best_simclr_run{run+1}.pth")
    
   

    # train the model with early stopping

    epochs = 35 # Keep the high epoch count, early stopping will decide when to stop
    patience =4 # Stop training if validation loss does not improve for 'patience' epochs
    min_delta = 0.001 # Minimum change to qualify as an improvement
    best_val_loss = float('inf') # Track best validation loss
    counter = 0 # Track consecutive epochs without improvement
    best_model_path = os.path.join(save_dir_simclr, f'best_simclr_run{run+1}.pth')

    train_losses = []
    valid_losses= []
    train_accuracies = []
    valid_accuracies= []

    # track best epoch metircs
    val_accuracy_at_best_loss = None
    train_accuracy_at_best_loss = None
    train_loss_at_best_loss = None
    val_loss_at_best_loss = None

    start_time = time.time()

    for epoch in range(epochs):
        model.train()
        epoch_train_loss = 0.0
        train_correct = 0
        total_train = 0
    
    # Run the training batches
        for b, (X_train, y_train) in enumerate(train_loader):
            b+=1
            X_train, y_train = X_train.to('cuda'), y_train.to('cuda')
        
            # forward pass
            outputs = model(X_train)
            loss = criterion(outputs, y_train)

            # backward propagation 
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            # track loos and accuracy
            epoch_train_loss += loss.item()
            preds = outputs.argmax(dim=1)
            train_correct += (preds == y_train).sum().item()
            total_train += y_train.size(0)

            # optional debug
            if b%20 == 0:
                print(f"Batch {b}, Loss: {loss.item():.4f}")

        avg_train_loss = epoch_train_loss / len(train_loader)
        train_accuracy = train_correct / total_train

        train_losses.append(avg_train_loss)
        train_accuracies.append(train_accuracy)

        # validation part
        model.eval()
        epoch_val_loss = 0.0
        val_correct = 0
        total_val = 0

        with torch.no_grad():
            for X_val, y_val in valid_loader:
                X_val, y_val = X_val.to('cuda'), y_val.to('cuda')

                outputs = model(X_val)
                loss = criterion(outputs, y_val)

                epoch_val_loss += loss.item()
                preds = outputs.argmax(dim=1)
                val_correct += (preds == y_val).sum().item()
                total_val += y_val.size(0)
       
           
        avg_val_loss = epoch_val_loss / len(valid_loader)
        val_accuracy = val_correct / total_val

        valid_losses.append(avg_val_loss)
        valid_accuracies.append(val_accuracy)

  

        print(f"Epoch: {epoch+1} - Train Loss: {avg_train_loss:.4f}, Train Acc: {train_accuracy:.4g} | "
              f"Val Loss: {avg_val_loss:.4f}, Val Acc: {val_accuracy:.4f}")
        scheduler.step(avg_train_loss)
      
        
        # **Early stopping logic**
        if avg_val_loss < best_val_loss - min_delta:
            best_val_loss = avg_val_loss # Update best loss
            val_accuracy_at_best_loss = val_accuracy
            train_accuracy_at_best_loss = train_accuracy
            train_loss_at_best_loss = avg_train_loss
            val_loss_at_best_loss = avg_val_loss

            counter = 0 # Reset counter
             # save the best model for this run
            torch.save(model.state_dict(), best_model_path)
            print(f"Best model saved at epoch {epoch+1}")
       
        else:
            counter += 1 # Increase counter
            if counter >= patience: # Stop if no improvement for 'patience' epochs
                print(f"Early stopping at epoch {epoch+1} (No improvement for {patience} epochs)")
                break
    #save metrics from each run
    all_train_acc.append(train_accuracy_at_best_loss)
    all_val_acc.append(val_accuracy_at_best_loss)
    all_train_loss.append(train_loss_at_best_loss)
    all_val_loss.append(val_loss_at_best_loss)   
    best_val_losses_all.append(best_val_loss)

    # save full per-epoch history
    train_accuracies_all.append(train_accuracies)
    valid_accuracies_all.append(valid_accuracies)
    train_losses_all.append(train_losses)
    valid_losses_all.append(valid_losses)

print(f'\nDuration: {time.time() - start_time:.0f} seconds') # Print time elapsed
# final results
print("\n===== Final Average Results ======\n")
print(f"Train Accuracy (best val loss): {np.mean(all_train_acc):.4f} +- {np.std(all_train_acc):.4f}")
print(f"Valid Accuracy: {np.mean(all_val_acc):.4f} +- {np.std(all_val_acc):.4f}")
print(f"Train Loss: {np.mean(all_train_loss):.4f} +- {np.std(all_train_loss):.4f}")
print(f"Valid Loss: {np.mean(all_val_loss):.4f} +- {np.std(all_val_loss):.4f}")

# save only the best model across runs
best_run_idx = np.argmin(best_val_losses_all)
best_model_path = os.path.join(save_dir_simclr, f"best_simclr_run{best_run_idx + 1}.pth")
final_best_model_path = os.path.join(save_dir_simclr, 'best_simclr_overall.pth')
shutil.copy(best_model_path, final_best_model_path)
print(f"n\Best overall model was from run {best_run_idx + 1} with val loss {best_val_losses_all[best_run_idx]:.4f}")
print(f"Saved as: {os.path.relpath(final_best_model_path)}")
# Out:
# ===== Run 1 =====
#
# Batch 20, Loss: 0.6975
# Batch 40, Loss: 0.6799
# Epoch: 1 - Train Loss: 0.6871, Train Acc: 0.5846 | Val Loss: 0.5650, Val Acc: 0.7786
# Best model saved at epoch 1
# Batch 20, Loss: 0.5777
# Batch 40, Loss: 0.4841
# Epoch: 2 - Train Loss: 0.5767, Train Acc: 0.7417 | Val Loss: 0.4515, Val Acc: 0.8601
# Best model saved at epoch 2
# Batch 20, Loss: 0.6237
# Batch 40, Loss: 0.5898
# Epoch: 3 - Train Loss: 0.5308, Train Acc: 0.785 | Val Loss: 0.3938, Val Acc: 0.8881
# Best model saved at epoch 3
# Batch 20, Loss: 0.4735
# Batch 40, Loss: 0.3451
# Epoch: 4 - Train Loss: 0.5093, Train Acc: 0.8063 | Val Loss: 0.3665, Val Acc: 0.8998
# Best model saved at epoch 4
# Batch 20, Loss: 0.4039
# Batch 40, Loss: 0.5258
# Epoch: 5 - Train Loss: 0.4924, Train Acc: 0.8149 | Val Loss: 0.3437, Val Acc: 0.9114
# Best model saved at epoch 5
# Batch 20, Loss: 0.5687
# Batch 40, Loss: 0.5986
# Epoch: 6 - Train Loss: 0.4846, Train Acc: 0.8169 | Val Loss: 0.3292, Val Acc: 0.9254
# Best model saved at epoch 6
# Batch 20, Loss: 0.4627
# Batch 40, Loss: 0.5300
# Epoch: 7 - Train Loss: 0.4844, Train Acc: 0.8182 | Val Loss: 0.3222, Val Acc: 0.9324
# Best model saved at epoch 7
# Batch 20, Loss: 0.4660
# Batch 40, Loss: 0.6385
# Epoch: 8 - Train Loss: 0.4747, Train Acc: 0.8282 | Val Loss: 0.3108, Val Acc: 0.9347
# Best model saved at epoch 8
# Batch 20, Loss: 0.3231
# Batch 40, Loss: 0.5140
# Epoch: 9 - Train Loss: 0.4698, Train Acc: 0.8322 | Val Loss: 0.3098, Val Acc: 0.9417
# Best model saved at epoch 9
# Batch 20, Loss: 0.4822
# Batch 40, Loss: 0.4398
# Epoch: 10 - Train Loss: 0.4735, Train Acc: 0.8249 | Val Loss: 0.3011, Val Acc: 0.9394
# Best model saved at epoch 10
# Batch 20, Loss: 0.5142
# Batch 40, Loss: 0.6892
# Epoch: 11 - Train Loss: 0.4650, Train Acc: 0.8309 | Val Loss: 0.2920, Val Acc: 0.9417
# Best model saved at epoch 11
# Batch 20, Loss: 0.5160
# Batch 40, Loss: 0.4081
# Epoch: 12 - Train Loss: 0.4641, Train Acc: 0.8356 | Val Loss: 0.2908, Val Acc: 0.9464
# Best model saved at epoch 12
# Batch 20, Loss: 0.4755
# Batch 40, Loss: 0.4380
# Epoch: 13 - Train Loss: 0.4714, Train Acc: 0.8249 | Val Loss: 0.2916, Val Acc: 0.9464
# Batch 20, Loss: 0.3304
# Batch 40, Loss: 0.3842
# Epoch: 14 - Train Loss: 0.4705, Train Acc: 0.8349 | Val Loss: 0.2998, Val Acc: 0.9441
# Batch 20, Loss: 0.3955
# Batch 40, Loss: 0.5274
# Epoch: 15 - Train Loss: 0.4612, Train Acc: 0.8389 | Val Loss: 0.2967, Val Acc: 0.9417
# Batch 20, Loss: 0.4071
# Batch 40, Loss: 0.4437
# Epoch: 16 - Train Loss: 0.4619, Train Acc: 0.8395 | Val Loss: 0.2861, Val Acc: 0.9557
# Best model saved at epoch 16
# Batch 20, Loss: 0.5909
# Batch 40, Loss: 0.3584
# Epoch: 17 - Train Loss: 0.4572, Train Acc: 0.8382 | Val Loss: 0.2839, Val Acc: 0.9487
# Best model saved at epoch 17
# Batch 20, Loss: 0.4304
# Batch 40, Loss: 0.4671
# Epoch: 18 - Train Loss: 0.4566, Train Acc: 0.8349 | Val Loss: 0.2843, Val Acc: 0.9487
# Batch 20, Loss: 0.3804
# Batch 40, Loss: 0.4433
# Epoch: 19 - Train Loss: 0.4557, Train Acc: 0.8449 | Val Loss: 0.2836, Val Acc: 0.9510
# Batch 20, Loss: 0.5886
# Batch 40, Loss: 0.3328
# Epoch: 20 - Train Loss: 0.4595, Train Acc: 0.8489 | Val Loss: 0.2820, Val Acc: 0.9557
# Best model saved at epoch 20
# Batch 20, Loss: 0.4266
# Batch 40, Loss: 0.3633
# Epoch: 21 - Train Loss: 0.4534, Train Acc: 0.8429 | Val Loss: 0.2844, Val Acc: 0.9510
# Batch 20, Loss: 0.3636
# Batch 40, Loss: 0.2961
# Epoch: 22 - Train Loss: 0.4539, Train Acc: 0.8395 | Val Loss: 0.2818, Val Acc: 0.9534
# Batch 20, Loss: 0.2739
# Batch 40, Loss: 0.3385
# Epoch: 23 - Train Loss: 0.4499, Train Acc: 0.8442 | Val Loss: 0.2813, Val Acc: 0.9580
# Batch 20, Loss: 0.3276
# Batch 40, Loss: 0.5119
# Epoch: 24 - Train Loss: 0.4536, Train Acc: 0.8382 | Val Loss: 0.2803, Val Acc: 0.9557
# Best model saved at epoch 24
# Batch 20, Loss: 0.6205
# Batch 40, Loss: 0.4714
# Epoch: 25 - Train Loss: 0.4557, Train Acc: 0.8395 | Val Loss: 0.2809, Val Acc: 0.9580
# Batch 20, Loss: 0.4874
# Batch 40, Loss: 0.5097
# Epoch: 26 - Train Loss: 0.4486, Train Acc: 0.8475 | Val Loss: 0.2822, Val Acc: 0.9510
# Batch 20, Loss: 0.5119
# Batch 40, Loss: 0.4146
# Epoch: 27 - Train Loss: 0.4610, Train Acc: 0.8369 | Val Loss: 0.2856, Val Acc: 0.9510
# Batch 20, Loss: 0.4399
# Batch 40, Loss: 0.6002
# Epoch: 28 - Train Loss: 0.4588, Train Acc: 0.8395 | Val Loss: 0.2856, Val Acc: 0.9510
# Early stopping at epoch 28 (No improvement for 4 epochs)
#
# ===== Run 2 =====
#
# Batch 20, Loss: 0.6334
# Batch 40, Loss: 0.6264
# Epoch: 1 - Train Loss: 0.6550, Train Acc: 0.6398 | Val Loss: 0.5387, Val Acc: 0.7762
# Best model saved at epoch 1
# Batch 20, Loss: 0.5185
# Batch 40, Loss: 0.5557
# Epoch: 2 - Train Loss: 0.5534, Train Acc: 0.761 | Val Loss: 0.4447, Val Acc: 0.8601
# Best model saved at epoch 2
# Batch 20, Loss: 0.5204
# Batch 40, Loss: 0.3564
# Epoch: 3 - Train Loss: 0.5062, Train Acc: 0.8076 | Val Loss: 0.3871, Val Acc: 0.8974
# Best model saved at epoch 3
# Batch 20, Loss: 0.4694
# Batch 40, Loss: 0.6104
# Epoch: 4 - Train Loss: 0.4917, Train Acc: 0.8036 | Val Loss: 0.3549, Val Acc: 0.9138
# Best model saved at epoch 4
# Batch 20, Loss: 0.4285
# Batch 40, Loss: 0.5264
# Epoch: 5 - Train Loss: 0.4861, Train Acc: 0.8169 | Val Loss: 0.3403, Val Acc: 0.9254
# Best model saved at epoch 5
# Batch 20, Loss: 0.5093
# Batch 40, Loss: 0.4989
# Epoch: 6 - Train Loss: 0.4774, Train Acc: 0.8189 | Val Loss: 0.3265, Val Acc: 0.9324
# Best model saved at epoch 6
# Batch 20, Loss: 0.4629
# Batch 40, Loss: 0.3638
# Epoch: 7 - Train Loss: 0.4727, Train Acc: 0.8242 | Val Loss: 0.3224, Val Acc: 0.9231
# Best model saved at epoch 7
# Batch 20, Loss: 0.4728
# Batch 40, Loss: 0.5324
# Epoch: 8 - Train Loss: 0.4741, Train Acc: 0.8296 | Val Loss: 0.3077, Val Acc: 0.9301
# Best model saved at epoch 8
# Batch 20, Loss: 0.4814
# Batch 40, Loss: 0.5546
# Epoch: 9 - Train Loss: 0.4687, Train Acc: 0.8276 | Val Loss: 0.3194, Val Acc: 0.9254
# Batch 20, Loss: 0.5264
# Batch 40, Loss: 0.4622
# Epoch: 10 - Train Loss: 0.4644, Train Acc: 0.8382 | Val Loss: 0.3080, Val Acc: 0.9277
# Batch 20, Loss: 0.3873
# Batch 40, Loss: 0.3658
# Epoch: 11 - Train Loss: 0.4627, Train Acc: 0.8389 | Val Loss: 0.3005, Val Acc: 0.9301
# Best model saved at epoch 11
# Batch 20, Loss: 0.6098
# Batch 40, Loss: 0.5664
# Epoch: 12 - Train Loss: 0.4677, Train Acc: 0.8342 | Val Loss: 0.2991, Val Acc: 0.9324
# Best model saved at epoch 12
# Batch 20, Loss: 0.4267
# Batch 40, Loss: 0.3617
# Epoch: 13 - Train Loss: 0.4653, Train Acc: 0.8316 | Val Loss: 0.2991, Val Acc: 0.9371
# Batch 20, Loss: 0.5059
# Batch 40, Loss: 0.4462
# Epoch: 14 - Train Loss: 0.4639, Train Acc: 0.8342 | Val Loss: 0.3048, Val Acc: 0.9347
# Batch 20, Loss: 0.3750
# Batch 40, Loss: 0.5246
# Epoch: 15 - Train Loss: 0.4591, Train Acc: 0.8362 | Val Loss: 0.3071, Val Acc: 0.9324
# Batch 20, Loss: 0.3427
# Batch 40, Loss: 0.4626
# Epoch: 16 - Train Loss: 0.4605, Train Acc: 0.8375 | Val Loss: 0.2908, Val Acc: 0.9417
# Best model saved at epoch 16
# Batch 20, Loss: 0.4579
# Batch 40, Loss: 0.5896
# Epoch: 17 - Train Loss: 0.4618, Train Acc: 0.8369 | Val Loss: 0.2925, Val Acc: 0.9417
# Batch 20, Loss: 0.4947
# Batch 40, Loss: 0.4784
# Epoch: 18 - Train Loss: 0.4554, Train Acc: 0.8415 | Val Loss: 0.2930, Val Acc: 0.9371
# Batch 20, Loss: 0.3916
# Batch 40, Loss: 0.4191
# Epoch: 19 - Train Loss: 0.4571, Train Acc: 0.8362 | Val Loss: 0.2977, Val Acc: 0.9394
# Batch 20, Loss: 0.5239
# Batch 40, Loss: 0.2976
# Epoch: 20 - Train Loss: 0.4569, Train Acc: 0.8409 | Val Loss: 0.2887, Val Acc: 0.9487
# Best model saved at epoch 20
# Batch 20, Loss: 0.4845
# Batch 40, Loss: 0.4004
# Epoch: 21 - Train Loss: 0.4534, Train Acc: 0.8342 | Val Loss: 0.2878, Val Acc: 0.9510
# Batch 20, Loss: 0.5370
# Batch 40, Loss: 0.5034
# Epoch: 22 - Train Loss: 0.4574, Train Acc: 0.8429 | Val Loss: 0.2901, Val Acc: 0.9464
# Batch 20, Loss: 0.4752
# Batch 40, Loss: 0.3707
# Epoch: 23 - Train Loss: 0.4474, Train Acc: 0.8429 | Val Loss: 0.2846, Val Acc: 0.9487
# Best model saved at epoch 23
# Batch 20, Loss: 0.5621
# Batch 40, Loss: 0.5146
# Epoch: 24 - Train Loss: 0.4524, Train Acc: 0.8409 | Val Loss: 0.2864, Val Acc: 0.9464
# Batch 20, Loss: 0.4685
# Batch 40, Loss: 0.3272
# Epoch: 25 - Train Loss: 0.4455, Train Acc: 0.8455 | Val Loss: 0.2838, Val Acc: 0.9510
# Batch 20, Loss: 0.4268
# Batch 40, Loss: 0.4604
# Epoch: 26 - Train Loss: 0.4526, Train Acc: 0.8389 | Val Loss: 0.2920, Val Acc: 0.9441
# Batch 20, Loss: 0.4554
# Batch 40, Loss: 0.4819
# Epoch: 27 - Train Loss: 0.4555, Train Acc: 0.8402 | Val Loss: 0.2836, Val Acc: 0.9487
# Early stopping at epoch 27 (No improvement for 4 epochs)
#
# ===== Run 3 =====
#
# Batch 20, Loss: 0.7036
# Batch 40, Loss: 0.6313
# Epoch: 1 - Train Loss: 0.6623, Train Acc: 0.5979 | Val Loss: 0.5012, Val Acc: 0.8578
# Best model saved at epoch 1
# Batch 20, Loss: 0.5136
# Batch 40, Loss: 0.5248
# Epoch: 2 - Train Loss: 0.5538, Train Acc: 0.771 | Val Loss: 0.3970, Val Acc: 0.9207
# Best model saved at epoch 2
# Batch 20, Loss: 0.5779
# Batch 40, Loss: 0.5457
# Epoch: 3 - Train Loss: 0.5140, Train Acc: 0.8129 | Val Loss: 0.3566, Val Acc: 0.9347
# Best model saved at epoch 3
# Batch 20, Loss: 0.4406
# Batch 40, Loss: 0.6000
# Epoch: 4 - Train Loss: 0.4930, Train Acc: 0.8322 | Val Loss: 0.3321, Val Acc: 0.9324
# Best model saved at epoch 4
# Batch 20, Loss: 0.4826
# Batch 40, Loss: 0.5462
# Epoch: 5 - Train Loss: 0.4853, Train Acc: 0.8242 | Val Loss: 0.3163, Val Acc: 0.9371
# Best model saved at epoch 5
# Batch 20, Loss: 0.3420
# Batch 40, Loss: 0.4988
# Epoch: 6 - Train Loss: 0.4814, Train Acc: 0.8242 | Val Loss: 0.3052, Val Acc: 0.9371
# Best model saved at epoch 6
# Batch 20, Loss: 0.5980
# Batch 40, Loss: 0.4864
# Epoch: 7 - Train Loss: 0.4786, Train Acc: 0.8282 | Val Loss: 0.3005, Val Acc: 0.9371
# Best model saved at epoch 7
# Batch 20, Loss: 0.5950
# Batch 40, Loss: 0.3536
# Epoch: 8 - Train Loss: 0.4671, Train Acc: 0.8342 | Val Loss: 0.2973, Val Acc: 0.9417
# Best model saved at epoch 8
# Batch 20, Loss: 0.3597
# Batch 40, Loss: 0.4353
# Epoch: 9 - Train Loss: 0.4703, Train Acc: 0.8302 | Val Loss: 0.3021, Val Acc: 0.9487
# Batch 20, Loss: 0.6023
# Batch 40, Loss: 0.6243
# Epoch: 10 - Train Loss: 0.4677, Train Acc: 0.8349 | Val Loss: 0.2956, Val Acc: 0.9464
# Best model saved at epoch 10
# Batch 20, Loss: 0.4108
# Batch 40, Loss: 0.5680
# Epoch: 11 - Train Loss: 0.4632, Train Acc: 0.8375 | Val Loss: 0.2860, Val Acc: 0.9441
# Best model saved at epoch 11
# Batch 20, Loss: 0.5874
# Batch 40, Loss: 0.4039
# Epoch: 12 - Train Loss: 0.4613, Train Acc: 0.8395 | Val Loss: 0.3015, Val Acc: 0.9347
# Batch 20, Loss: 0.6734
# Batch 40, Loss: 0.5326
# Epoch: 13 - Train Loss: 0.4631, Train Acc: 0.8455 | Val Loss: 0.2899, Val Acc: 0.9464
# Batch 20, Loss: 0.3780
# Batch 40, Loss: 0.6246
# Epoch: 14 - Train Loss: 0.4521, Train Acc: 0.8495 | Val Loss: 0.2883, Val Acc: 0.9487
# Batch 20, Loss: 0.4149
# Batch 40, Loss: 0.6048
# Epoch: 15 - Train Loss: 0.4578, Train Acc: 0.8316 | Val Loss: 0.2841, Val Acc: 0.9464
# Best model saved at epoch 15
# Batch 20, Loss: 0.4412
# Batch 40, Loss: 0.5545
# Epoch: 16 - Train Loss: 0.4629, Train Acc: 0.8395 | Val Loss: 0.2810, Val Acc: 0.9487
# Best model saved at epoch 16
# Batch 20, Loss: 0.5640
# Batch 40, Loss: 0.3523
# Epoch: 17 - Train Loss: 0.4592, Train Acc: 0.8316 | Val Loss: 0.2846, Val Acc: 0.9441
# Batch 20, Loss: 0.4385
# Batch 40, Loss: 0.5316
# Epoch: 18 - Train Loss: 0.4530, Train Acc: 0.8415 | Val Loss: 0.2857, Val Acc: 0.9441
# Batch 20, Loss: 0.5451
# Batch 40, Loss: 0.6523
# Epoch: 19 - Train Loss: 0.4602, Train Acc: 0.8375 | Val Loss: 0.2800, Val Acc: 0.9487
# Best model saved at epoch 19
# Batch 20, Loss: 0.5603
# Batch 40, Loss: 0.3749
# Epoch: 20 - Train Loss: 0.4532, Train Acc: 0.8449 | Val Loss: 0.2796, Val Acc: 0.9510
# Batch 20, Loss: 0.3366
# Batch 40, Loss: 0.3335
# Epoch: 21 - Train Loss: 0.4579, Train Acc: 0.8395 | Val Loss: 0.2828, Val Acc: 0.9557
# Batch 20, Loss: 0.5455
# Batch 40, Loss: 0.3407
# Epoch: 22 - Train Loss: 0.4514, Train Acc: 0.8382 | Val Loss: 0.2800, Val Acc: 0.9441
# Batch 20, Loss: 0.4471
# Batch 40, Loss: 0.4365
# Epoch: 23 - Train Loss: 0.4520, Train Acc: 0.8415 | Val Loss: 0.2789, Val Acc: 0.9464
# Best model saved at epoch 23
# Batch 20, Loss: 0.3953
# Batch 40, Loss: 0.4384
# Epoch: 24 - Train Loss: 0.4547, Train Acc: 0.8415 | Val Loss: 0.2824, Val Acc: 0.9487
# Batch 20, Loss: 0.2981
# Batch 40, Loss: 0.5780
# Epoch: 25 - Train Loss: 0.4653, Train Acc: 0.8435 | Val Loss: 0.2799, Val Acc: 0.9557
# Batch 20, Loss: 0.4838
# Batch 40, Loss: 0.4456
# Epoch: 26 - Train Loss: 0.4509, Train Acc: 0.8449 | Val Loss: 0.2781, Val Acc: 0.9557
# Batch 20, Loss: 0.4328
# Batch 40, Loss: 0.3252
# Epoch: 27 - Train Loss: 0.4562, Train Acc: 0.8462 | Val Loss: 0.2805, Val Acc: 0.9604
# Early stopping at epoch 27 (No improvement for 4 epochs)
#
# Duration: 651 seconds
#
# ===== Final Average Results ======
#
# Train Accuracy (best val loss): 0.8409 +- 0.0020
# Valid Accuracy: 0.9503 +- 0.0040
# Train Loss: 0.4510 +- 0.0026
# Valid Loss: 0.2813 +- 0.0024
# n\Best overall model was from run 3 with val loss 0.2789
# Saved as: base_simclr_new/best_simclr_overall.pth

# %%
# save full simCLR model 
torch.save(encoder.state_dict(), os.path.join(save_dir_simclr, 'best_simclr_encoder_only.pth'))

# %%
model = LinearClassifier(encoder = encoder, feature_dim=512, num_classes=2).to(device)

# %%
model_dir = os.path.join(PROJECT_ROOT, 'base_simclr_new')
model_filename = 'best_simclr_overall.pth'
model_path = os.path.join(model_dir, model_filename)

# %%
model.load_state_dict(torch.load(model_path))
model  = model.to(device)
model.eval()
# Out:
# LinearClassifier(
#   (encoder): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#     (fc): Identity()
#   )
#   (classifier): Linear(in_features=512, out_features=2, bias=True)
# )

# %%
import seaborn as sns
model.eval()
all_preds = []
all_labels = []
with torch.no_grad():
    for images, labels in valid_loader:
        images = images.to('cuda')
        labels = labels.to('cuda')

        outputs = model(images)
        _, preds = torch.max(outputs,1)

        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

# %%
print("classification_report:\n")
print(classification_report(all_labels, all_preds))
# Out:
# classification_report:
#
#               precision    recall  f1-score   support
#
#            0       0.92      0.97      0.95       210
#            1       0.97      0.92      0.95       219
#
#     accuracy                           0.95       429
#    macro avg       0.95      0.95      0.95       429
# weighted avg       0.95      0.95      0.95       429

# %%
# confusion matrix
# visulize train and valid loss
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(all_labels, all_preds)
plt.figure(figsize=(6,4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Non-Tumor', 'Tumor'],
            yticklabels=['Non-Tumor','Tumor'])
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.tight_layout()
plt.show()

# %%
max_len = max(len(run) for run in train_accuracies_all)

# %%
def pad_to_max(arr_list, max_len):
    return np.array([np.pad(run, (0, max_len - len(run)), constant_values=np.nan) for run in arr_list])

train_accuracies_pad = pad_to_max(train_accuracies_all, max_len)
valid_accuracies_pad = pad_to_max(valid_accuracies_all, max_len)
train_losses_pad = pad_to_max(train_losses_all, max_len)
valid_losses_pad = pad_to_max(valid_losses_all, max_len)

# %%
epochs = list(range(1, max_len + 1))
mean_train_acc = np.nanmean(train_accuracies_pad, axis=0)
std_train_acc = np.nanstd(train_accuracies_pad, axis=0)

mean_valid_acc = np.nanmean(valid_accuracies_pad, axis=0)
std_valid_acc = np.nanstd(valid_accuracies_pad, axis=0)


plt.figure(figsize = (8,5))
plt.plot(epochs, mean_train_acc, label='Train Accuracy', color = 'blue')
plt.fill_between(epochs, mean_train_acc - std_train_acc, mean_train_acc + std_train_acc, alpha = 0.1, color = 'blue')

plt.plot(epochs, mean_valid_acc, label='Valid Accuracy', color = 'orange')
plt.fill_between(epochs, mean_valid_acc - std_valid_acc, mean_valid_acc + std_valid_acc, alpha = 0.1, color = 'orange')

plt.title('Accuracy over Epochs (+-std)')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
def pad_to_max(loss_list, max_len):
    return np.array([np.pad(run, (0, max_len - len(run)), constant_values=np.nan) for run in loss_list])


train_losses_pad = pad_to_max(train_losses_all, max_len)
valid_losses_pad = pad_to_max(valid_losses_all, max_len)

# %%
epochs = list(range(1, max_len + 1))
mean_train_loss = np.nanmean(train_losses_pad, axis=0)
std_train_loss = np.nanstd(train_losses_pad, axis=0)

mean_valid_loss = np.nanmean(valid_losses_pad, axis=0)
std_valid_loss = np.nanstd(valid_losses_pad,axis=0)

epochs = list(range(1, len(mean_train_loss)+1))

plt.figure(figsize = (8,5))
plt.plot(epochs, mean_train_loss, label='Train Loss', color = 'blue')
plt.fill_between(epochs, mean_train_loss - std_train_loss, mean_train_loss + std_train_loss, alpha = 0.1, color = 'blue')

plt.plot(epochs, mean_valid_loss, label='Valid Loss', color = 'orange')
plt.fill_between(epochs, mean_valid_loss - std_valid_loss, mean_valid_loss + std_valid_loss, alpha = 0.1, color = 'orange')

plt.title('Loss over Epochs (+-std)')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
