# %%
import os
import torch
import torchvision.models as models
import torchvision.transforms as transforms
from torch import nn, optim
from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder
from torchvision import datasets, transforms, models # add models to the list
from sklearn.metrics import classification_report

# %%
# check if GPU is available 
torch.cuda.is_available()
# Out:
# True

# %%
PROJECT_ROOT = os.getcwd()

# %%
train_path = PROJECT_ROOT+'/train/'
validation_path = PROJECT_ROOT +'/validation/'

# %%
# define transformers
train_transform = transforms.Compose([
        transforms.RandomAffine(degrees=0, shear=5, scale=(0.95,1.05)),
        transforms.RandomRotation(3),      
        transforms.RandomHorizontalFlip(p=0.5),  # reverse 50% of images
        transforms.RandomVerticalFlip(p=0.3),  # reverse 30% of images
        transforms.GaussianBlur(3, sigma=(0.1, 1.0)),
        transforms.Resize(224),             # resize shortest side to 224 pixels
        transforms.CenterCrop(224),         # crop longest side to 224 pixels at center
        transforms.ToTensor(),
        transforms.Normalize([0.5],[0.5])
    ])


valid_transform = transforms.Compose([
        transforms.Resize(224),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.5],[0.5])
    ])

# %%
import json
from torch.utils.data import Dataset
from PIL import Image
from glob import glob

# %%
class TumorDataset(Dataset):
    def __init__(self, data_path, transform=None):
        
        self.samples = []
        self.label_map = {
            'no_tumor': 0,
            'tumor': 1
            }
        for label_name, label_value in self.label_map.items():
            folder_path = os.path.join(data_path, label_name)
            image_paths = glob(os.path.join(folder_path, '*'))

            for image_path in image_paths:
                self.samples.append((
                    image_path, label_value
                    ))   
            self.transform = transform

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        image_path, label = self.samples[idx]
        image = Image.open(image_path).convert('RGB')
        if self.transform:
            image = self.transform(image)
        return image, label

# %%
train_data = TumorDataset(
    data_path = train_path,
    transform=train_transform
)
valid_data = TumorDataset(
    data_path = validation_path,
    transform = valid_transform   
)

# %%
# start to load pre-trained ResNet18 model and fine-tune
import os
import time
from tqdm import tqdm
import numpy as np
import random
import torch
import torch.nn as nn
from torchvision import models
from torchvision.models import vit_b_16, ViT_B_16_Weights
from torch.optim.lr_scheduler import CosineAnnealingLR
import shutil

save_dir_vit = os.path.join(PROJECT_ROOT, 'Vit_B_16')
os.makedirs(save_dir_vit,exist_ok = True)

num_runs = 3
train_accuracies_all = []
valid_accuracies_all = []
train_losses_all = []
valid_losses_all = []
all_train_acc = []
all_val_acc =[]
all_train_loss = []
all_val_loss =[]
# track the best val loss of each run 
best_val_losses_all = []



for run in range(num_runs):
    print(f"\n===== Run {run+1} =====\n")
    torch.manual_seed(42 + run)
    torch.cuda.manual_seed(42 + run)
    np.random.seed(42 + run)
    random.seed(42 + run)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    train_loader = DataLoader(train_data, batch_size = 32, shuffle=True)
    valid_loader = DataLoader(valid_data, batch_size = 32, shuffle=True)

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    # load pretrained ResNet18 model
    model = models.vit_b_16(weights=ViT_B_16_Weights.DEFAULT)
    # freeze all layers
    for param in model.parameters():
        param.requires_grad = False
    
    # unfreeze last 2 transformer blocks and the classification head
    for name, param in model.named_parameters():
        if "encoder.layers.7" in name or "encoder.layers.8" in name or "encoder.layers.9" in name or "encoder.layers.10" in name or "encoder.layers.11" in name or "heads" in name:
            param.requires_grad = True
    

    model.heads = nn.Sequential(
        nn.Dropout(0.4),
        nn.Linear(model.heads.head.in_features, 2)
    
    )
    model = model.to(device)
    
    # define the loss and optimizer 
    criterion = nn.CrossEntropyLoss(label_smoothing=0.05)
    opt_Vit = torch.optim.Adam(model.parameters(), lr=3e-4, weight_decay = 1e-5)
    scheduler = CosineAnnealingLR(opt_Vit, T_max =50, eta_min=1e-6)

    best_val_acc = 0
    best_model_path= os.path.join(save_dir_vit, f"best_vit_run{run+1}.pth")
    

    # train the model with early stopping

    epochs = 50 # Keep the high epoch count, early stopping will decide when to stop
    patience =6 # Stop training if validation loss does not improve for 'patience' epochs
    min_delta = 0.001 # Minimum change to qualify as an improvement
    best_val_loss = float('inf') # Track best validation loss
    counter = 0 # Track consecutive epochs without improvement
    best_model_path = os.path.join(save_dir_vit, f'best_vit_run{run+1}.pth')

    train_losses = []
    valid_losses= []
    train_accuracies = []
    valid_accuracies= []

     # track best epoch metircs
    val_accuracy_at_best_loss = None
    train_accuracy_at_best_loss = None
    train_loss_at_best_loss = None
    val_loss_at_best_loss = None

    start_time = time.time()

    for epoch in range(epochs):
        model.train()
        epoch_train_loss = 0.0
        train_correct = 0
        total_train = 0
    
    # Run the training batches
        for b, (X_train, y_train) in enumerate(train_loader):
            b+=1
            X_train, y_train = X_train.to('cuda'), y_train.to('cuda')
        
            # forward pass
            outputs = model(X_train)
            loss = criterion(outputs, y_train)

            # backward propagation 
            opt_Vit.zero_grad()
            loss.backward()
            opt_Vit.step()

            # track loos and accuracy
            epoch_train_loss += loss.item()
            preds = outputs.argmax(dim=1)
            train_correct += (preds == y_train).sum().item()
            total_train += y_train.size(0)

            # optional debug
            if b%20 == 0:
                print(f"Batch {b}, Loss: {loss.item():.4f}")

        avg_train_loss = epoch_train_loss / len(train_loader)
        train_accuracy = train_correct / total_train

        train_losses.append(avg_train_loss)
        train_accuracies.append(train_accuracy)

        # validation part
        model.eval()
        epoch_val_loss = 0.0
        val_correct = 0
        total_val = 0

        with torch.no_grad():
            for X_val, y_val in valid_loader:
                X_val, y_val = X_val.to('cuda'), y_val.to('cuda')

                outputs = model(X_val)
                loss = criterion(outputs, y_val)

                epoch_val_loss += loss.item()
                preds = outputs.argmax(dim=1)
                val_correct += (preds == y_val).sum().item()
                total_val += y_val.size(0)
       
           
        avg_val_loss = epoch_val_loss / len(valid_loader)
        val_accuracy = val_correct / total_val

        valid_losses.append(avg_val_loss)
        valid_accuracies.append(val_accuracy)

  

        print(f"Epoch: {epoch+1} - Train Loss: {avg_train_loss:.4f}, Train Acc: {train_accuracy:.4g} | "
              f"Val Loss: {avg_val_loss:.4f}, Val Acc: {val_accuracy:.4f}")
      
        
        # **Early stopping logic**
        if avg_val_loss < best_val_loss - min_delta:
            best_val_loss = avg_val_loss # Update best loss
            val_accuracy_at_best_loss = val_accuracy
            train_accuracy_at_best_loss = train_accuracy
            train_loss_at_best_loss = avg_train_loss
            val_loss_at_best_loss = avg_val_loss
            counter = 0 # Reset counter

            # save the best model for this run
            torch.save(model.state_dict(), best_model_path)
            print(f"Best model saved at epoch {epoch+1}")
        else:
            counter += 1 # Increase counter
            if counter >= patience: # Stop if no improvement for 'patience' epochs
                print(f"Early stopping at epoch {epoch+1} (No improvement for {patience} epochs)")
                break
    #save metrics from each run
    all_train_acc.append(train_accuracy_at_best_loss)
    all_val_acc.append(val_accuracy_at_best_loss)
    all_train_loss.append(train_loss_at_best_loss)
    all_val_loss.append(val_loss_at_best_loss)   
    best_val_losses_all.append(best_val_loss)

    # save full per-epoch history
    train_accuracies_all.append(train_accuracies)
    valid_accuracies_all.append(valid_accuracies)
    train_losses_all.append(train_losses)
    valid_losses_all.append(valid_losses)

print(f'\nDuration: {time.time() - start_time:.0f} seconds') # Print time elapsed
# final results
print("\n===== Final Average Results ======\n")
print(f"Train Accuracy: {np.mean(all_train_acc):.4f} +- {np.std(all_train_acc):.4f}")
print(f"Valid Accuracy: {np.mean(all_val_acc):.4f} +- {np.std(all_val_acc):.4f}")
print(f"Train Loss: {np.mean(all_train_loss):.4f} +- {np.std(all_train_loss):.4f}")
print(f"Valid Loss: {np.mean(all_val_loss):.4f} +- {np.std(all_val_loss):.4f}")

# save only the best model across runs
best_run_idx = np.argmin(best_val_losses_all)
best_model_path = os.path.join(save_dir_vit, f"best_vit_run{best_run_idx + 1}.pth")
final_best_model_path = os.path.join(save_dir_vit, 'best_vit_overall.pth')
shutil.copy(best_model_path, final_best_model_path)
print(f"n\Best overall model was from run {best_run_idx + 1} with val loss {best_val_losses_all[best_run_idx]:.4f}")
print("\nsaved to:", os.path.relpath(final_best_model_path))
# Out:
# ===== Run 1 =====
# Batch 20, Loss: 0.4045
# Batch 40, Loss: 0.2413
# Batch 60, Loss: 0.2174
# Epoch: 1 - Train Loss: 0.4366, Train Acc: 0.8152 | Val Loss: 0.3194, Val Acc: 0.8977
# Best model saved at epoch 1
# Batch 20, Loss: 0.2437
# Batch 40, Loss: 0.2901
# Batch 60, Loss: 0.2457
# Epoch: 2 - Train Loss: 0.2948, Train Acc: 0.9019 | Val Loss: 0.2644, Val Acc: 0.9047
# Best model saved at epoch 2
# Batch 20, Loss: 0.4354
# Batch 40, Loss: 0.2336
# Batch 60, Loss: 0.2158
# Epoch: 3 - Train Loss: 0.2657, Train Acc: 0.9228 | Val Loss: 0.2421, Val Acc: 0.9302
# Best model saved at epoch 3
# Batch 20, Loss: 0.2189
# Batch 40, Loss: 0.2487
# Batch 60, Loss: 0.2041
# Epoch: 4 - Train Loss: 0.2479, Train Acc: 0.9308 | Val Loss: 0.2305, Val Acc: 0.9372
# Best model saved at epoch 4
# Batch 20, Loss: 0.1950
# Batch 40, Loss: 0.2280
# Batch 60, Loss: 0.2076
# Epoch: 5 - Train Loss: 0.2289, Train Acc: 0.9462 | Val Loss: 0.2237, Val Acc: 0.9488
# Best model saved at epoch 5
# Batch 20, Loss: 0.2853
# Batch 40, Loss: 0.1724
# Batch 60, Loss: 0.2105
# Epoch: 6 - Train Loss: 0.2256, Train Acc: 0.9487 | Val Loss: 0.2191, Val Acc: 0.9512
# Best model saved at epoch 6
# Batch 20, Loss: 0.3168
# Batch 40, Loss: 0.1862
# Batch 60, Loss: 0.1315
# Epoch: 7 - Train Loss: 0.2137, Train Acc: 0.9532 | Val Loss: 0.2128, Val Acc: 0.9558
# Best model saved at epoch 7
# Batch 20, Loss: 0.1768
# Batch 40, Loss: 0.1967
# Batch 60, Loss: 0.2622
# Epoch: 8 - Train Loss: 0.2203, Train Acc: 0.9537 | Val Loss: 0.2108, Val Acc: 0.9581
# Best model saved at epoch 8
# Batch 20, Loss: 0.2403
# Batch 40, Loss: 0.1941
# Batch 60, Loss: 0.2063
# Epoch: 9 - Train Loss: 0.2113, Train Acc: 0.9626 | Val Loss: 0.2071, Val Acc: 0.9558
# Best model saved at epoch 9
# Batch 20, Loss: 0.1404
# Batch 40, Loss: 0.1480
# Batch 60, Loss: 0.2253
# Epoch: 10 - Train Loss: 0.2099, Train Acc: 0.9592 | Val Loss: 0.2022, Val Acc: 0.9581
# Best model saved at epoch 10
# Batch 20, Loss: 0.1842
# Batch 40, Loss: 0.2462
# Batch 60, Loss: 0.1668
# Epoch: 11 - Train Loss: 0.2042, Train Acc: 0.9656 | Val Loss: 0.2022, Val Acc: 0.9581
# Batch 20, Loss: 0.2802
# Batch 40, Loss: 0.2406
# Batch 60, Loss: 0.1859
# Epoch: 12 - Train Loss: 0.2044, Train Acc: 0.9641 | Val Loss: 0.2083, Val Acc: 0.9628
# Batch 20, Loss: 0.2245
# Batch 40, Loss: 0.2320
# Batch 60, Loss: 0.1627
# Epoch: 13 - Train Loss: 0.2052, Train Acc: 0.9622 | Val Loss: 0.1979, Val Acc: 0.9628
# Best model saved at epoch 13
# Batch 20, Loss: 0.1410
# Batch 40, Loss: 0.1828
# Batch 60, Loss: 0.1478
# Epoch: 14 - Train Loss: 0.2064, Train Acc: 0.9651 | Val Loss: 0.1946, Val Acc: 0.9605
# Best model saved at epoch 14
# Batch 20, Loss: 0.2313
# Batch 40, Loss: 0.2028
# Batch 60, Loss: 0.1976
# Epoch: 15 - Train Loss: 0.1992, Train Acc: 0.9626 | Val Loss: 0.1926, Val Acc: 0.9605
# Best model saved at epoch 15
# Batch 20, Loss: 0.1448
# Batch 40, Loss: 0.1687
# Batch 60, Loss: 0.2032
# Epoch: 16 - Train Loss: 0.1967, Train Acc: 0.9661 | Val Loss: 0.1984, Val Acc: 0.9628
# Batch 20, Loss: 0.3065
# Batch 40, Loss: 0.1536
# Batch 60, Loss: 0.2518
# Epoch: 17 - Train Loss: 0.2000, Train Acc: 0.9661 | Val Loss: 0.1930, Val Acc: 0.9605
# Batch 20, Loss: 0.1546
# Batch 40, Loss: 0.1583
# Batch 60, Loss: 0.1727
# Epoch: 18 - Train Loss: 0.1997, Train Acc: 0.9661 | Val Loss: 0.1882, Val Acc: 0.9628
# Epoch: 31 - Train Loss: 0.1863, Train Acc: 0.9716 | Val Loss: 0.1859, Val Acc: 0.9698
# Batch 20, Loss: 0.2569
# Batch 40, Loss: 0.2296
# Batch 60, Loss: 0.1600
# Epoch: 32 - Train Loss: 0.1939, Train Acc: 0.9691 | Val Loss: 0.1797, Val Acc: 0.9721
# Best model saved at epoch 32
# Batch 20, Loss: 0.1944
# Batch 40, Loss: 0.1783
# Batch 60, Loss: 0.1618
# Epoch: 33 - Train Loss: 0.1900, Train Acc: 0.9696 | Val Loss: 0.1809, Val Acc: 0.9698
# Batch 20, Loss: 0.1723
# Batch 40, Loss: 0.1392
# Batch 60, Loss: 0.1645
# Epoch: 34 - Train Loss: 0.1864, Train Acc: 0.9686 | Val Loss: 0.1834, Val Acc: 0.9698
# Batch 20, Loss: 0.1602
# Batch 40, Loss: 0.1669
# Batch 60, Loss: 0.1806
# Epoch: 35 - Train Loss: 0.1889, Train Acc: 0.9696 | Val Loss: 0.1857, Val Acc: 0.9674
# Batch 20, Loss: 0.2445
# Batch 40, Loss: 0.2335
# Batch 60, Loss: 0.1496
# Epoch: 36 - Train Loss: 0.1933, Train Acc: 0.9666 | Val Loss: 0.1818, Val Acc: 0.9721
# Batch 20, Loss: 0.1747
# Batch 40, Loss: 0.2304
# Batch 60, Loss: 0.1448
# Epoch: 37 - Train Loss: 0.1886, Train Acc: 0.9686 | Val Loss: 0.1885, Val Acc: 0.9674
# Batch 20, Loss: 0.1568
# Batch 40, Loss: 0.1616
# Batch 60, Loss: 0.1700
# Epoch: 38 - Train Loss: 0.1873, Train Acc: 0.9726 | Val Loss: 0.1827, Val Acc: 0.9721
# Early stopping at epoch 38 (No improvement for 6 epochs)
#
# ===== Run 2 =====
#
# Batch 20, Loss: 0.3520
# Batch 40, Loss: 0.3163
# Batch 60, Loss: 0.2787
# Epoch: 1 - Train Loss: 0.3579, Train Acc: 0.871 | Val Loss: 0.2922, Val Acc: 0.9047
# Best model saved at epoch 1
# Batch 20, Loss: 0.2409
# Batch 40, Loss: 0.2816
# Batch 60, Loss: 0.2699
# Epoch: 2 - Train Loss: 0.2754, Train Acc: 0.9178 | Val Loss: 0.2486, Val Acc: 0.9256
# Best model saved at epoch 2
# Batch 20, Loss: 0.2146
# Batch 40, Loss: 0.2903
# Batch 60, Loss: 0.2419
# Epoch: 3 - Train Loss: 0.2428, Train Acc: 0.9358 | Val Loss: 0.2428, Val Acc: 0.9279
# Best model saved at epoch 3
# Batch 20, Loss: 0.2335
# Batch 40, Loss: 0.2025
# Batch 60, Loss: 0.1910
# Epoch: 4 - Train Loss: 0.2348, Train Acc: 0.9422 | Val Loss: 0.2257, Val Acc: 0.9395
# Best model saved at epoch 4
# Batch 20, Loss: 0.2044
# Batch 40, Loss: 0.2374
# Batch 60, Loss: 0.1991
# Epoch: 5 - Train Loss: 0.2292, Train Acc: 0.9472 | Val Loss: 0.2206, Val Acc: 0.9395
# Best model saved at epoch 5
# Batch 20, Loss: 0.2021
# Batch 40, Loss: 0.1791
# Batch 60, Loss: 0.1563
# Epoch: 6 - Train Loss: 0.2214, Train Acc: 0.9497 | Val Loss: 0.2169, Val Acc: 0.9419
# Best model saved at epoch 6
# Batch 20, Loss: 0.1812
# Batch 40, Loss: 0.2386
# Batch 60, Loss: 0.2556
# Epoch: 7 - Train Loss: 0.2213, Train Acc: 0.9517 | Val Loss: 0.2164, Val Acc: 0.9419
# Batch 20, Loss: 0.1998
# Batch 40, Loss: 0.1968
# Batch 60, Loss: 0.2478
# Epoch: 8 - Train Loss: 0.2155, Train Acc: 0.9547 | Val Loss: 0.2040, Val Acc: 0.9535
# Best model saved at epoch 8
# Batch 20, Loss: 0.1559
# Batch 40, Loss: 0.2292
# Batch 60, Loss: 0.1622
# Epoch: 9 - Train Loss: 0.2089, Train Acc: 0.9577 | Val Loss: 0.2183, Val Acc: 0.9558
# Batch 20, Loss: 0.1749
# Batch 40, Loss: 0.1569
# Batch 60, Loss: 0.1731
# Epoch: 10 - Train Loss: 0.2059, Train Acc: 0.9602 | Val Loss: 0.1995, Val Acc: 0.9535
# Best model saved at epoch 10
# Batch 20, Loss: 0.3110
# Batch 40, Loss: 0.1621
# Batch 60, Loss: 0.1571
# Epoch: 11 - Train Loss: 0.2035, Train Acc: 0.9631 | Val Loss: 0.1981, Val Acc: 0.9581
# Best model saved at epoch 11
# Batch 20, Loss: 0.1881
# Batch 40, Loss: 0.2419
# Batch 60, Loss: 0.1854
# Epoch: 12 - Train Loss: 0.2060, Train Acc: 0.9622 | Val Loss: 0.1960, Val Acc: 0.9605
# Best model saved at epoch 12
# Batch 20, Loss: 0.2614
# Batch 40, Loss: 0.1643
# Batch 60, Loss: 0.1525
# Epoch: 13 - Train Loss: 0.2017, Train Acc: 0.9631 | Val Loss: 0.1963, Val Acc: 0.9605
# Batch 20, Loss: 0.1942
# Batch 40, Loss: 0.1494
# Batch 60, Loss: 0.1393
# Epoch: 14 - Train Loss: 0.2006, Train Acc: 0.9631 | Val Loss: 0.1992, Val Acc: 0.9628
# Batch 20, Loss: 0.2165
# Batch 40, Loss: 0.1637
# Batch 60, Loss: 0.2356
# Epoch: 15 - Train Loss: 0.1984, Train Acc: 0.9661 | Val Loss: 0.1960, Val Acc: 0.9628
# Batch 20, Loss: 0.2470
# Batch 40, Loss: 0.1682
# Batch 60, Loss: 0.1320
# Epoch: 16 - Train Loss: 0.1958, Train Acc: 0.9661 | Val Loss: 0.1957, Val Acc: 0.9628
# Batch 20, Loss: 0.1708
# Batch 40, Loss: 0.1873
# Batch 60, Loss: 0.2842
# Epoch: 17 - Train Loss: 0.1967, Train Acc: 0.9691 | Val Loss: 0.1895, Val Acc: 0.9628
# Best model saved at epoch 17
# Batch 20, Loss: 0.1792
# Batch 40, Loss: 0.1921
# Batch 60, Loss: 0.1837
# Batch 40, Loss: 0.1946
# Batch 60, Loss: 0.2745
# Epoch: 7 - Train Loss: 0.2170, Train Acc: 0.9572 | Val Loss: 0.2128, Val Acc: 0.9605
# Best model saved at epoch 7
# Batch 20, Loss: 0.2345
# Batch 40, Loss: 0.2904
# Batch 60, Loss: 0.1554
# Epoch: 8 - Train Loss: 0.2113, Train Acc: 0.9542 | Val Loss: 0.2063, Val Acc: 0.9651
# Best model saved at epoch 8
# Batch 20, Loss: 0.1628
# Batch 40, Loss: 0.2664
# Batch 60, Loss: 0.2814
# Epoch: 9 - Train Loss: 0.2072, Train Acc: 0.9617 | Val Loss: 0.2044, Val Acc: 0.9651
# Best model saved at epoch 9
# Batch 20, Loss: 0.2541
# Batch 40, Loss: 0.1921
# Batch 60, Loss: 0.1839
# Epoch: 10 - Train Loss: 0.2051, Train Acc: 0.9557 | Val Loss: 0.1985, Val Acc: 0.9628
# Best model saved at epoch 10
# Batch 20, Loss: 0.1317
# Batch 40, Loss: 0.1850
# Batch 60, Loss: 0.1651
# Epoch: 11 - Train Loss: 0.2054, Train Acc: 0.9597 | Val Loss: 0.1950, Val Acc: 0.9628
# Best model saved at epoch 11
# Batch 20, Loss: 0.2101
# Batch 40, Loss: 0.2271
# Batch 60, Loss: 0.1762
# Epoch: 12 - Train Loss: 0.1973, Train Acc: 0.9661 | Val Loss: 0.1952, Val Acc: 0.9628
# Batch 20, Loss: 0.2584
# Batch 40, Loss: 0.2036
# Batch 60, Loss: 0.2086
# Epoch: 13 - Train Loss: 0.2018, Train Acc: 0.9612 | Val Loss: 0.1958, Val Acc: 0.9651
# Batch 20, Loss: 0.2283
# Batch 40, Loss: 0.1691
# Batch 60, Loss: 0.1378
# Epoch: 14 - Train Loss: 0.1974, Train Acc: 0.9651 | Val Loss: 0.1928, Val Acc: 0.9628
# Best model saved at epoch 14
# Batch 20, Loss: 0.1461
# Batch 40, Loss: 0.1877
# Batch 60, Loss: 0.2064
# Epoch: 15 - Train Loss: 0.2020, Train Acc: 0.9617 | Val Loss: 0.1919, Val Acc: 0.9628
# Batch 20, Loss: 0.1741
# Batch 40, Loss: 0.1895
# Batch 60, Loss: 0.2506
# Epoch: 16 - Train Loss: 0.1958, Train Acc: 0.9681 | Val Loss: 0.1914, Val Acc: 0.9651
# Best model saved at epoch 16
# Batch 20, Loss: 0.2023
# Batch 40, Loss: 0.2289
# Batch 60, Loss: 0.2789
# Epoch: 17 - Train Loss: 0.1966, Train Acc: 0.9651 | Val Loss: 0.1871, Val Acc: 0.9628
# Best model saved at epoch 17
# Batch 20, Loss: 0.2446
# Batch 40, Loss: 0.1710
# Batch 60, Loss: 0.1556
# Epoch: 18 - Train Loss: 0.1958, Train Acc: 0.9651 | Val Loss: 0.1962, Val Acc: 0.9651
# Batch 20, Loss: 0.1603
# Batch 40, Loss: 0.2112
# Batch 60, Loss: 0.2080
# Epoch: 19 - Train Loss: 0.1906, Train Acc: 0.9666 | Val Loss: 0.1926, Val Acc: 0.9651
# Batch 20, Loss: 0.2288
# Batch 40, Loss: 0.2410
# Batch 60, Loss: 0.1954
# Epoch: 20 - Train Loss: 0.1940, Train Acc: 0.9686 | Val Loss: 0.1869, Val Acc: 0.9698
# Batch 20, Loss: 0.1719
# Batch 40, Loss: 0.1487
# Batch 60, Loss: 0.1565
# Epoch: 21 - Train Loss: 0.1955, Train Acc: 0.9681 | Val Loss: 0.1870, Val Acc: 0.9674
# Batch 20, Loss: 0.1627
# Batch 40, Loss: 0.1849
# Batch 60, Loss: 0.2644
# Epoch: 22 - Train Loss: 0.1947, Train Acc: 0.9726 | Val Loss: 0.1886, Val Acc: 0.9651
# Batch 20, Loss: 0.1529
# Batch 40, Loss: 0.2878
# Batch 60, Loss: 0.1833
# Epoch: 23 - Train Loss: 0.1852, Train Acc: 0.9766 | Val Loss: 0.1822, Val Acc: 0.9744
# Best model saved at epoch 23
# Batch 20, Loss: 0.1405
# Batch 40, Loss: 0.1965
# Batch 60, Loss: 0.1347
# Epoch: 24 - Train Loss: 0.1903, Train Acc: 0.9701 | Val Loss: 0.1834, Val Acc: 0.9744
# Batch 20, Loss: 0.1482
# Batch 40, Loss: 0.1897
# Batch 60, Loss: 0.3564
# Epoch: 25 - Train Loss: 0.1945, Train Acc: 0.9726 | Val Loss: 0.1867, Val Acc: 0.9674
# Batch 20, Loss: 0.1628
# Batch 40, Loss: 0.1930
# Batch 60, Loss: 0.1650
# Epoch: 26 - Train Loss: 0.1916, Train Acc: 0.9706 | Val Loss: 0.1859, Val Acc: 0.9674
# Batch 20, Loss: 0.1943
# Batch 40, Loss: 0.1520
# Batch 60, Loss: 0.1763
# Epoch: 27 - Train Loss: 0.1907, Train Acc: 0.9711 | Val Loss: 0.1850, Val Acc: 0.9674
# Batch 20, Loss: 0.1436
# Batch 40, Loss: 0.2075
# Batch 60, Loss: 0.1614
# Epoch: 28 - Train Loss: 0.1875, Train Acc: 0.9726 | Val Loss: 0.1835, Val Acc: 0.9721
# Batch 20, Loss: 0.1746
# Batch 40, Loss: 0.1596
# Batch 60, Loss: 0.1475
# Epoch: 29 - Train Loss: 0.1873, Train Acc: 0.9726 | Val Loss: 0.1880, Val Acc: 0.9674
# Early stopping at epoch 29 (No improvement for 6 epochs)
#
# Duration: 2014 seconds
#
# ===== Final Average Results ======
#
# Train Accuracy: 0.9705 +- 0.0046
# Valid Accuracy: 0.9736 +- 0.0011
# Train Loss: 0.1912 +- 0.0043
# Valid Loss: 0.1797 +- 0.0021
# n\Best overall model was from run 2 with val loss 0.1771
#
# saved to: Vit_B_16/best_vit_overall.pth

# %%
# visulize train and valid loss
import matplotlib.pyplot as plt
import numpy as np

# %%
max_len = max(len(run) for run in train_accuracies_all)

# %%
def pad_to_max(arr_list, max_len):
    return np.array([np.pad(run, (0, max_len - len(run)), constant_values=np.nan) for run in arr_list])

train_accuracies_pad = pad_to_max(train_accuracies_all, max_len)
valid_accuracies_pad = pad_to_max(valid_accuracies_all, max_len)
train_losses_pad = pad_to_max(train_losses_all, max_len)
valid_losses_pad = pad_to_max(valid_losses_all, max_len)

# %%
epochs = list(range(1, max_len + 1))
mean_train_acc = np.nanmean(train_accuracies_pad, axis=0)
std_train_acc = np.nanstd(train_accuracies_pad, axis=0)

mean_valid_acc = np.nanmean(valid_accuracies_pad, axis=0)
std_valid_acc = np.nanstd(valid_accuracies_pad, axis=0)


plt.figure(figsize = (8,5))
plt.plot(epochs, mean_train_acc, label='Train accuracy', color = 'blue')
plt.fill_between(epochs, mean_train_acc - std_train_acc, mean_train_acc + std_train_acc, alpha = 0.1, color = 'blue')

plt.plot(epochs, mean_valid_acc, label='Valid accuracy', color = 'orange')
plt.fill_between(epochs, mean_valid_acc - std_valid_acc, mean_valid_acc + std_valid_acc, alpha = 0.1, color = 'orange')

plt.title('')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
def pad_to_max(loss_list, max_len):
    return np.array([np.pad(run, (0, max_len - len(run)), constant_values=np.nan) for run in loss_list])

#train_losses_pad = pad_to_max(train_losses_all, max_len)
#valid_losses_pad = pad_to_max(valid_losses_all, max_len)
train_losses_pad = pad_to_max(train_losses_all, max_len)
valid_losses_pad = pad_to_max(valid_losses_all, max_len)

# %%
epochs = list(range(1, max_len + 1))
mean_train_loss = np.nanmean(train_losses_pad, axis=0)
std_train_loss = np.nanstd(train_losses_pad, axis=0)

mean_valid_loss = np.nanmean(valid_losses_pad, axis=0)
std_valid_loss = np.nanstd(valid_losses_pad,axis=0)

epochs = list(range(1, len(mean_train_loss)+1))

plt.figure(figsize = (8,5))
plt.plot(epochs, mean_train_loss, label='Train loss', color = 'blue')
plt.fill_between(epochs, mean_train_loss - std_train_loss, mean_train_loss + std_train_loss, alpha = 0.1, color = 'blue')

plt.plot(epochs, mean_valid_loss, label='Valid loss', color = 'orange')
plt.fill_between(epochs, mean_valid_loss - std_valid_loss, mean_valid_loss + std_valid_loss, alpha = 0.1, color = 'orange')

plt.title('')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
model_dir = os.path.join(PROJECT_ROOT, 'Vit_B_16')
model_filename= 'best_vit_overall.pth'
model_path= os.path.join(model_dir, model_filename)

# %%
model.load_state_dict(torch.load(model_path))
model  = model.to(device)
model.eval()
# Out:
# VisionTransformer(
#   (conv_proj): Conv2d(3, 768, kernel_size=(16, 16), stride=(16, 16))
#   (encoder): Encoder(
#     (dropout): Dropout(p=0.0, inplace=False)
#     (layers): Sequential(
#       (encoder_layer_0): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_1): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_2): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_3): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_4): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_5): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_6): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_7): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_8): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_9): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_10): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_11): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (ln): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#   )
#   (heads): Sequential(
#     (0): Dropout(p=0.4, inplace=False)
#     (1): Linear(in_features=768, out_features=2, bias=True)
#   )
# )

# %%
import seaborn as sns
all_preds = []
all_labels = []
with torch.no_grad():
    for images, labels in valid_loader:
        images = images.to('cuda')
        labels = labels.to('cuda')

        outputs = model(images)
        _, preds = torch.max(outputs,1)

        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

# %%
print("classification_report:\n")
print(classification_report(all_labels, all_preds))
# Out:
# classification_report:
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.85      0.90        59
#            1       0.98      0.99      0.99       371
#
#     accuracy                           0.97       430
#    macro avg       0.97      0.92      0.94       430
# weighted avg       0.97      0.97      0.97       430

# %%
# confusion matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(all_labels, all_preds)
plt.figure(figsize=(6,4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Nontumor', 'Tumor'],
            yticklabels=['Nontumor','Tumor'])
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.title('')
plt.tight_layout()
plt.show()
