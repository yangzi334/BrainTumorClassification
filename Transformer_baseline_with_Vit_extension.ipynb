# %%
import os
import torch
import torchvision.models as models
import torchvision.transforms as transforms
from torch import nn, optim
from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder
from torchvision import datasets, transforms, models # add models to the list
from sklearn.metrics import classification_report

# %%
# check if GPU is available 
torch.cuda.is_available()
# Out:
# True

# %%
PROJECT_ROOT = os.getcwd()

# %%
train_path = PROJECT_ROOT+'/train/'
validation_path = PROJECT_ROOT +'/validation/'

# %%
# define transformers
train_transform = transforms.Compose([
        transforms.RandomAffine(degrees=0, shear=5, scale=(0.95,1.05)),
        transforms.RandomRotation(3),      
        transforms.RandomHorizontalFlip(p=0.5),  # reverse 50% of images
        transforms.RandomVerticalFlip(p=0.3),  # reverse 30% of images
        transforms.GaussianBlur(3, sigma=(0.1, 1.0)),
        transforms.Resize(224),             # resize shortest side to 224 pixels
        transforms.CenterCrop(224),         # crop longest side to 224 pixels at center
        transforms.ToTensor(),
        transforms.Normalize([0.5],[0.5])
    ])


valid_transform = transforms.Compose([
        transforms.Resize(224),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.5],[0.5])
    ])

# %%
import json
from torch.utils.data import Dataset
from PIL import Image
from glob import glob

# %%
class TumorDataset(Dataset):
    def __init__(self, data_path, transform=None):
        
        self.samples = []
        self.label_map = {
            'no_tumor': 0,
            'tumor': 1
            }
        for label_name, label_value in self.label_map.items():
            folder_path = os.path.join(data_path, label_name)
            image_paths = glob(os.path.join(folder_path, '*'))

            for image_path in image_paths:
                self.samples.append((
                    image_path, label_value
                    ))   
            self.transform = transform

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        image_path, label = self.samples[idx]
        image = Image.open(image_path).convert('RGB')
        if self.transform:
            image = self.transform(image)
        return image, label

# %%
train_data = TumorDataset(
    data_path = train_path,
    transform=train_transform
)
valid_data = TumorDataset(
    data_path = validation_path,
    transform = valid_transform   
)

# %%
# start to load pre-trained ResNet18 model and fine-tune
import os
import time
from tqdm import tqdm
import numpy as np
import random
import torch
import torch.nn as nn
from torchvision import models
from torchvision.models import vit_b_16, ViT_B_16_Weights
from torch.optim.lr_scheduler import CosineAnnealingLR
import shutil

save_dir_vit_extension = os.path.join(PROJECT_ROOT, 'base_Vit_B_16_new_extension')
os.makedirs(save_dir_vit_extension,exist_ok = True)

num_runs = 3
train_accuracies_all = []
valid_accuracies_all = []
train_losses_all = []
valid_losses_all = []
all_train_acc = []
all_val_acc =[]
all_train_loss = []
all_val_loss =[]
# track the best val loss of each run 
best_val_losses_all = []



for run in range(num_runs):
    print(f"\n===== Run {run+1} =====\n")
    torch.manual_seed(42 + run)
    torch.cuda.manual_seed(42 + run)
    np.random.seed(42 + run)
    random.seed(42 + run)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    train_loader = DataLoader(train_data, batch_size = 32, shuffle=True)
    valid_loader = DataLoader(valid_data, batch_size = 32, shuffle=True)

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    # load pretrained ResNet18 model
    model = models.vit_b_16(weights=ViT_B_16_Weights.DEFAULT)
    # freeze all layers
    for param in model.parameters():
        param.requires_grad = False
    
    # unfreeze last 2 transformer blocks and the classification head
    for name, param in model.named_parameters():
        if "encoder.layers.7" in name or "encoder.layers.8" in name or "encoder.layers.9" in name or "encoder.layers.10" in name or "encoder.layers.11" in name or "heads" in name:
            param.requires_grad = True
    

    model.heads = nn.Sequential(
        nn.Dropout(0.4),
        nn.Linear(model.heads.head.in_features, 2)
    
    )
    model = model.to(device)
    
    # define the loss and optimizer 
    criterion = nn.CrossEntropyLoss(label_smoothing=0.05)
    opt_Vit = torch.optim.Adam(model.parameters(), lr=3e-4, weight_decay = 1e-5)
    scheduler = CosineAnnealingLR(opt_Vit, T_max =50, eta_min=1e-6)

    best_val_acc = 0
    best_model_path_extension = os.path.join(save_dir_vit_extension, f"best_vit_extension_run{run+1}.pth")
    

    # train the model with early stopping

    epochs = 50 # Keep the high epoch count, early stopping will decide when to stop
    patience =6 # Stop training if validation loss does not improve for 'patience' epochs
    min_delta = 0.001 # Minimum change to qualify as an improvement
    best_val_loss = float('inf') # Track best validation loss
    counter = 0 # Track consecutive epochs without improvement
    best_model_path_extension = os.path.join(save_dir_vit_extension, f'best_vit_extension_run{run+1}.pth')

    train_losses = []
    valid_losses= []
    train_accuracies = []
    valid_accuracies= []

     # track best epoch metircs
    val_accuracy_at_best_loss = None
    train_accuracy_at_best_loss = None
    train_loss_at_best_loss = None
    val_loss_at_best_loss = None

    start_time = time.time()

    for epoch in range(epochs):
        model.train()
        epoch_train_loss = 0.0
        train_correct = 0
        total_train = 0
    
    # Run the training batches
        for b, (X_train, y_train) in enumerate(train_loader):
            b+=1
            X_train, y_train = X_train.to('cuda'), y_train.to('cuda')
        
            # forward pass
            outputs = model(X_train)
            loss = criterion(outputs, y_train)

            # backward propagation 
            opt_Vit.zero_grad()
            loss.backward()
            opt_Vit.step()

            # track loos and accuracy
            epoch_train_loss += loss.item()
            preds = outputs.argmax(dim=1)
            train_correct += (preds == y_train).sum().item()
            total_train += y_train.size(0)

            # optional debug
            if b%20 == 0:
                print(f"Batch {b}, Loss: {loss.item():.4f}")

        avg_train_loss = epoch_train_loss / len(train_loader)
        train_accuracy = train_correct / total_train

        train_losses.append(avg_train_loss)
        train_accuracies.append(train_accuracy)

        # validation part
        model.eval()
        epoch_val_loss = 0.0
        val_correct = 0
        total_val = 0

        with torch.no_grad():
            for X_val, y_val in valid_loader:
                X_val, y_val = X_val.to('cuda'), y_val.to('cuda')

                outputs = model(X_val)
                loss = criterion(outputs, y_val)

                epoch_val_loss += loss.item()
                preds = outputs.argmax(dim=1)
                val_correct += (preds == y_val).sum().item()
                total_val += y_val.size(0)
       
           
        avg_val_loss = epoch_val_loss / len(valid_loader)
        val_accuracy = val_correct / total_val

        valid_losses.append(avg_val_loss)
        valid_accuracies.append(val_accuracy)

  

        print(f"Epoch: {epoch+1} - Train Loss: {avg_train_loss:.4f}, Train Acc: {train_accuracy:.4g} | "
              f"Val Loss: {avg_val_loss:.4f}, Val Acc: {val_accuracy:.4f}")
      
        
        # **Early stopping logic**
        if avg_val_loss < best_val_loss - min_delta:
            best_val_loss = avg_val_loss # Update best loss
            val_accuracy_at_best_loss = val_accuracy
            train_accuracy_at_best_loss = train_accuracy
            train_loss_at_best_loss = avg_train_loss
            val_loss_at_best_loss = avg_val_loss
            counter = 0 # Reset counter

            # save the best model for this run
            torch.save(model.state_dict(), best_model_path_extension)
            print(f"Best model saved at epoch {epoch+1}")
        else:
            counter += 1 # Increase counter
            if counter >= patience: # Stop if no improvement for 'patience' epochs
                print(f"Early stopping at epoch {epoch+1} (No improvement for {patience} epochs)")
                break
    #save metrics from each run
    all_train_acc.append(train_accuracy_at_best_loss)
    all_val_acc.append(val_accuracy_at_best_loss)
    all_train_loss.append(train_loss_at_best_loss)
    all_val_loss.append(val_loss_at_best_loss)   
    best_val_losses_all.append(best_val_loss)

    # save full per-epoch history
    train_accuracies_all.append(train_accuracies)
    valid_accuracies_all.append(valid_accuracies)
    train_losses_all.append(train_losses)
    valid_losses_all.append(valid_losses)

print(f'\nDuration: {time.time() - start_time:.0f} seconds') # Print time elapsed
# final results
print("\n===== Final Average Results ======\n")
print(f"Train Accuracy: {np.mean(all_train_acc):.4f} +- {np.std(all_train_acc):.4f}")
print(f"Valid Accuracy: {np.mean(all_val_acc):.4f} +- {np.std(all_val_acc):.4f}")
print(f"Train Loss: {np.mean(all_train_loss):.4f} +- {np.std(all_train_loss):.4f}")
print(f"Valid Loss: {np.mean(all_val_loss):.4f} +- {np.std(all_val_loss):.4f}")

# save only the best model across runs
best_run_idx = np.argmin(best_val_losses_all)
best_model_path_extension = os.path.join(save_dir_vit_extension, f"best_vit_extension_run{best_run_idx + 1}.pth")
final_best_model_path_extension = os.path.join(save_dir_vit_extension, 'best_vit_extension_overall.pth')
shutil.copy(best_model_path_extension, final_best_model_path_extension)
print(f"n\Best overall model was from run {best_run_idx + 1} with val loss {best_val_losses_all[best_run_idx]:.4f}")
print("\nsaved to:", os.path.relpath(final_best_model_path_extension))
# Out:
# ===== Run 1 =====
#
# Batch 20, Loss: 0.5114
# Batch 40, Loss: 0.2630
# Batch 60, Loss: 0.2507
# Epoch: 1 - Train Loss: 0.4347, Train Acc: 0.8242 | Val Loss: 0.3104, Val Acc: 0.9000
# Best model saved at epoch 1
# Batch 20, Loss: 0.2514
# Batch 40, Loss: 0.2130
# Batch 60, Loss: 0.2856
# Epoch: 2 - Train Loss: 0.2873, Train Acc: 0.9069 | Val Loss: 0.2518, Val Acc: 0.9116
# Best model saved at epoch 2
# Batch 20, Loss: 0.2967
# Batch 40, Loss: 0.2700
# Batch 60, Loss: 0.1961
# Epoch: 3 - Train Loss: 0.2640, Train Acc: 0.9248 | Val Loss: 0.2279, Val Acc: 0.9326
# Best model saved at epoch 3
# Batch 20, Loss: 0.1929
# Batch 40, Loss: 0.2896
# Batch 60, Loss: 0.3257
# Epoch: 4 - Train Loss: 0.2474, Train Acc: 0.9293 | Val Loss: 0.2146, Val Acc: 0.9512
# Best model saved at epoch 4
# Batch 20, Loss: 0.1435
# Batch 40, Loss: 0.2579
# Batch 60, Loss: 0.2250
# Epoch: 5 - Train Loss: 0.2363, Train Acc: 0.9417 | Val Loss: 0.2069, Val Acc: 0.9605
# Best model saved at epoch 5
# Batch 20, Loss: 0.2430
# Batch 40, Loss: 0.1879
# Batch 60, Loss: 0.1492
# Epoch: 6 - Train Loss: 0.2347, Train Acc: 0.9442 | Val Loss: 0.2014, Val Acc: 0.9651
# Best model saved at epoch 6
# Batch 20, Loss: 0.2925
# Batch 40, Loss: 0.2118
# Batch 60, Loss: 0.1444
# Epoch: 7 - Train Loss: 0.2247, Train Acc: 0.9512 | Val Loss: 0.1950, Val Acc: 0.9651
# Best model saved at epoch 7
# Batch 20, Loss: 0.2632
# Batch 40, Loss: 0.1695
# Batch 60, Loss: 0.2049
# Epoch: 8 - Train Loss: 0.2182, Train Acc: 0.9547 | Val Loss: 0.1896, Val Acc: 0.9674
# Best model saved at epoch 8
# Batch 20, Loss: 0.2368
# Batch 40, Loss: 0.1634
# Batch 60, Loss: 0.2292
# Epoch: 9 - Train Loss: 0.2108, Train Acc: 0.9592 | Val Loss: 0.1917, Val Acc: 0.9651
# Batch 20, Loss: 0.1846
# Batch 40, Loss: 0.1803
# Batch 60, Loss: 0.1568
# Epoch: 10 - Train Loss: 0.2154, Train Acc: 0.9542 | Val Loss: 0.1894, Val Acc: 0.9651
# Batch 20, Loss: 0.2564
# Batch 40, Loss: 0.2464
# Batch 60, Loss: 0.1683
# Epoch: 11 - Train Loss: 0.2159, Train Acc: 0.9502 | Val Loss: 0.1832, Val Acc: 0.9721
# Best model saved at epoch 11
# Batch 20, Loss: 0.3064
# Batch 40, Loss: 0.1908
# Batch 60, Loss: 0.3113
# Epoch: 12 - Train Loss: 0.2012, Train Acc: 0.9676 | Val Loss: 0.1801, Val Acc: 0.9698
# Best model saved at epoch 12
# Batch 20, Loss: 0.3555
# Batch 40, Loss: 0.1834
# Batch 60, Loss: 0.1595
# Epoch: 13 - Train Loss: 0.2132, Train Acc: 0.9557 | Val Loss: 0.1769, Val Acc: 0.9721
# Best model saved at epoch 13
# Batch 20, Loss: 0.2547
# Batch 40, Loss: 0.2008
# Batch 60, Loss: 0.2082
# Epoch: 14 - Train Loss: 0.2079, Train Acc: 0.9636 | Val Loss: 0.1749, Val Acc: 0.9721
# Best model saved at epoch 14
# Batch 20, Loss: 0.1920
# Batch 40, Loss: 0.1771
# Batch 60, Loss: 0.2092
# Epoch: 15 - Train Loss: 0.2017, Train Acc: 0.9646 | Val Loss: 0.1758, Val Acc: 0.9721
# Batch 20, Loss: 0.2332
# Batch 40, Loss: 0.1734
# Batch 60, Loss: 0.1780
# Epoch: 16 - Train Loss: 0.2025, Train Acc: 0.9607 | Val Loss: 0.1773, Val Acc: 0.9674
# Batch 20, Loss: 0.1925
# Batch 40, Loss: 0.2760
# Batch 60, Loss: 0.1844
# Epoch: 17 - Train Loss: 0.1996, Train Acc: 0.9641 | Val Loss: 0.1760, Val Acc: 0.9698
# Batch 20, Loss: 0.1452
# Batch 40, Loss: 0.1544
# Batch 60, Loss: 0.1563
# Epoch: 18 - Train Loss: 0.1993, Train Acc: 0.9666 | Val Loss: 0.1731, Val Acc: 0.9721
# Best model saved at epoch 18
# Batch 20, Loss: 0.1767
# Batch 40, Loss: 0.1579
# Batch 60, Loss: 0.2065
# Epoch: 19 - Train Loss: 0.1951, Train Acc: 0.9651 | Val Loss: 0.1699, Val Acc: 0.9744
# Best model saved at epoch 19
# Batch 20, Loss: 0.1966
# Batch 40, Loss: 0.2417
# Batch 60, Loss: 0.2329
# Epoch: 20 - Train Loss: 0.1948, Train Acc: 0.9666 | Val Loss: 0.1705, Val Acc: 0.9744
# Batch 20, Loss: 0.1835
# Batch 40, Loss: 0.2093
# Batch 60, Loss: 0.1603
# Epoch: 21 - Train Loss: 0.1944, Train Acc: 0.9696 | Val Loss: 0.1715, Val Acc: 0.9698
# Batch 20, Loss: 0.1862
# Batch 40, Loss: 0.2223
# Batch 60, Loss: 0.2153
# Epoch: 22 - Train Loss: 0.2009, Train Acc: 0.9617 | Val Loss: 0.1686, Val Acc: 0.9744
# Best model saved at epoch 22
# Batch 20, Loss: 0.2512
# Batch 40, Loss: 0.2107
# Batch 60, Loss: 0.2623
# Epoch: 23 - Train Loss: 0.1969, Train Acc: 0.9681 | Val Loss: 0.1696, Val Acc: 0.9744
# Batch 20, Loss: 0.2032
# Batch 40, Loss: 0.2190
# Batch 60, Loss: 0.2055
# Epoch: 24 - Train Loss: 0.1976, Train Acc: 0.9651 | Val Loss: 0.1763, Val Acc: 0.9721
# Batch 20, Loss: 0.1572
# Batch 40, Loss: 0.1738
# Batch 60, Loss: 0.2949
# Epoch: 25 - Train Loss: 0.1999, Train Acc: 0.9622 | Val Loss: 0.1695, Val Acc: 0.9767
# Batch 20, Loss: 0.1481
# Batch 40, Loss: 0.1774
# Batch 60, Loss: 0.1454
# Epoch: 26 - Train Loss: 0.1905, Train Acc: 0.9706 | Val Loss: 0.1705, Val Acc: 0.9744
# Batch 20, Loss: 0.2480
# Batch 40, Loss: 0.1526
# Batch 60, Loss: 0.2082
# Epoch: 27 - Train Loss: 0.1961, Train Acc: 0.9656 | Val Loss: 0.1726, Val Acc: 0.9767
# Batch 20, Loss: 0.1932
# Batch 40, Loss: 0.1673
# Batch 60, Loss: 0.2254
# Epoch: 28 - Train Loss: 0.1903, Train Acc: 0.9686 | Val Loss: 0.1668, Val Acc: 0.9814
# Best model saved at epoch 28
# Batch 20, Loss: 0.2533
# Batch 40, Loss: 0.3109
# Batch 60, Loss: 0.2038
# Epoch: 29 - Train Loss: 0.1928, Train Acc: 0.9721 | Val Loss: 0.1685, Val Acc: 0.9767
# Batch 20, Loss: 0.1999
# Batch 40, Loss: 0.1576
# Batch 60, Loss: 0.1398
# Epoch: 30 - Train Loss: 0.1949, Train Acc: 0.9671 | Val Loss: 0.1682, Val Acc: 0.9791
# Batch 20, Loss: 0.1986
# Batch 40, Loss: 0.1621
# Batch 60, Loss: 0.1807
# Epoch: 31 - Train Loss: 0.1932, Train Acc: 0.9676 | Val Loss: 0.1707, Val Acc: 0.9767
# Batch 20, Loss: 0.1613
# Batch 40, Loss: 0.1928
# Batch 60, Loss: 0.1660
# Epoch: 32 - Train Loss: 0.1962, Train Acc: 0.9646 | Val Loss: 0.1682, Val Acc: 0.9791
# Batch 20, Loss: 0.1804
# Batch 40, Loss: 0.2847
# Batch 60, Loss: 0.1391
# Epoch: 33 - Train Loss: 0.1937, Train Acc: 0.9686 | Val Loss: 0.1679, Val Acc: 0.9767
# Batch 20, Loss: 0.2143
# Batch 40, Loss: 0.1661
# Batch 60, Loss: 0.1734
# Epoch: 34 - Train Loss: 0.1935, Train Acc: 0.9711 | Val Loss: 0.1819, Val Acc: 0.9767
# Early stopping at epoch 34 (No improvement for 6 epochs)
#
# ===== Run 2 =====
#
# Batch 20, Loss: 0.3140
# Batch 40, Loss: 0.3320
# Batch 60, Loss: 0.2758
# Epoch: 1 - Train Loss: 0.3601, Train Acc: 0.8735 | Val Loss: 0.2739, Val Acc: 0.9047
# Best model saved at epoch 1
# Batch 20, Loss: 0.2247
# Batch 40, Loss: 0.3011
# Batch 60, Loss: 0.3218
# Epoch: 2 - Train Loss: 0.2743, Train Acc: 0.9124 | Val Loss: 0.2300, Val Acc: 0.9349
# Best model saved at epoch 2
# Batch 20, Loss: 0.2349
# Batch 40, Loss: 0.3287
# Batch 60, Loss: 0.2276
# Epoch: 3 - Train Loss: 0.2549, Train Acc: 0.9273 | Val Loss: 0.2173, Val Acc: 0.9442
# Best model saved at epoch 3
# Batch 20, Loss: 0.4574
# Batch 40, Loss: 0.1649
# Batch 60, Loss: 0.1687
# Epoch: 4 - Train Loss: 0.2433, Train Acc: 0.9412 | Val Loss: 0.2013, Val Acc: 0.9605
# Best model saved at epoch 4
# Batch 20, Loss: 0.2186
# Batch 40, Loss: 0.2448
# Batch 60, Loss: 0.1696
# Epoch: 5 - Train Loss: 0.2290, Train Acc: 0.9522 | Val Loss: 0.1936, Val Acc: 0.9651
# Best model saved at epoch 5
# Batch 20, Loss: 0.1594
# Batch 40, Loss: 0.2091
# Batch 60, Loss: 0.2493
# Epoch: 6 - Train Loss: 0.2232, Train Acc: 0.9487 | Val Loss: 0.1882, Val Acc: 0.9674
# Best model saved at epoch 6
# Batch 20, Loss: 0.1882
# Batch 40, Loss: 0.2081
# Batch 60, Loss: 0.1718
# Epoch: 7 - Train Loss: 0.2191, Train Acc: 0.9507 | Val Loss: 0.1944, Val Acc: 0.9674
# Batch 20, Loss: 0.2013
# Batch 40, Loss: 0.2168
# Batch 60, Loss: 0.1597
# Epoch: 8 - Train Loss: 0.2155, Train Acc: 0.9512 | Val Loss: 0.1868, Val Acc: 0.9698
# Best model saved at epoch 8
# Batch 20, Loss: 0.2047
# Batch 40, Loss: 0.2805
# Batch 60, Loss: 0.1968
# Epoch: 9 - Train Loss: 0.2115, Train Acc: 0.9562 | Val Loss: 0.1845, Val Acc: 0.9744
# Best model saved at epoch 9
# Batch 20, Loss: 0.1677
# Batch 40, Loss: 0.1612
# Batch 60, Loss: 0.2503
# Epoch: 10 - Train Loss: 0.2113, Train Acc: 0.9562 | Val Loss: 0.1810, Val Acc: 0.9674
# Best model saved at epoch 10
# Batch 20, Loss: 0.2677
# Batch 40, Loss: 0.2202
# Batch 60, Loss: 0.2347
# Epoch: 11 - Train Loss: 0.2094, Train Acc: 0.9597 | Val Loss: 0.1826, Val Acc: 0.9674
# Batch 20, Loss: 0.2495
# Batch 40, Loss: 0.2872
# Batch 60, Loss: 0.1840
# Epoch: 12 - Train Loss: 0.2107, Train Acc: 0.9567 | Val Loss: 0.1764, Val Acc: 0.9674
# Best model saved at epoch 12
# Batch 20, Loss: 0.1960
# Batch 40, Loss: 0.2030
# Batch 60, Loss: 0.1798
# Epoch: 13 - Train Loss: 0.2042, Train Acc: 0.9651 | Val Loss: 0.1789, Val Acc: 0.9674
# Batch 20, Loss: 0.1729
# Batch 40, Loss: 0.1573
# Batch 60, Loss: 0.2073
# Epoch: 14 - Train Loss: 0.1989, Train Acc: 0.9622 | Val Loss: 0.1806, Val Acc: 0.9698
# Batch 20, Loss: 0.2588
# Batch 40, Loss: 0.1745
# Batch 60, Loss: 0.1895
# Epoch: 15 - Train Loss: 0.2002, Train Acc: 0.9651 | Val Loss: 0.1787, Val Acc: 0.9698
# Batch 20, Loss: 0.1783
# Batch 40, Loss: 0.2057
# Batch 60, Loss: 0.1987
# Epoch: 16 - Train Loss: 0.2013, Train Acc: 0.9612 | Val Loss: 0.1768, Val Acc: 0.9721
# Batch 20, Loss: 0.3186
# Batch 40, Loss: 0.1785
# Batch 60, Loss: 0.1501
# Epoch: 17 - Train Loss: 0.2008, Train Acc: 0.9602 | Val Loss: 0.1722, Val Acc: 0.9698
# Best model saved at epoch 17
# Batch 20, Loss: 0.2755
# Batch 40, Loss: 0.2106
# Batch 60, Loss: 0.2198
# Epoch: 18 - Train Loss: 0.1936, Train Acc: 0.9676 | Val Loss: 0.1731, Val Acc: 0.9767
# Batch 20, Loss: 0.2047
# Batch 40, Loss: 0.1558
# Batch 60, Loss: 0.1548
# Epoch: 19 - Train Loss: 0.2010, Train Acc: 0.9612 | Val Loss: 0.1726, Val Acc: 0.9698
# Batch 20, Loss: 0.1666
# Batch 40, Loss: 0.3127
# Batch 60, Loss: 0.1896
# Epoch: 20 - Train Loss: 0.1999, Train Acc: 0.9676 | Val Loss: 0.1814, Val Acc: 0.9721
# Batch 20, Loss: 0.1459
# Batch 40, Loss: 0.1917
# Batch 60, Loss: 0.2290
# Epoch: 21 - Train Loss: 0.1967, Train Acc: 0.9691 | Val Loss: 0.1690, Val Acc: 0.9767
# Best model saved at epoch 21
# Batch 20, Loss: 0.3096
# Batch 40, Loss: 0.1433
# Batch 60, Loss: 0.1377
# Epoch: 22 - Train Loss: 0.2011, Train Acc: 0.9626 | Val Loss: 0.1693, Val Acc: 0.9744
# Batch 20, Loss: 0.1620
# Batch 40, Loss: 0.1649
# Batch 60, Loss: 0.1550
# Epoch: 23 - Train Loss: 0.1955, Train Acc: 0.9671 | Val Loss: 0.1707, Val Acc: 0.9744
# Batch 20, Loss: 0.1684
# Batch 40, Loss: 0.2457
# Batch 60, Loss: 0.2389
# Epoch: 24 - Train Loss: 0.2001, Train Acc: 0.9622 | Val Loss: 0.1830, Val Acc: 0.9698
# Batch 20, Loss: 0.1637
# Batch 40, Loss: 0.1593
# Batch 60, Loss: 0.1813
# Epoch: 25 - Train Loss: 0.1900, Train Acc: 0.9661 | Val Loss: 0.1659, Val Acc: 0.9814
# Best model saved at epoch 25
# Batch 20, Loss: 0.2275
# Batch 40, Loss: 0.2284
# Batch 60, Loss: 0.1803
# Epoch: 26 - Train Loss: 0.1971, Train Acc: 0.9671 | Val Loss: 0.1669, Val Acc: 0.9814
# Batch 20, Loss: 0.1689
# Batch 40, Loss: 0.1792
# Batch 60, Loss: 0.1642
# Epoch: 27 - Train Loss: 0.1954, Train Acc: 0.9691 | Val Loss: 0.1676, Val Acc: 0.9791
# Batch 20, Loss: 0.2177
# Batch 40, Loss: 0.1370
# Batch 60, Loss: 0.2121
# Epoch: 28 - Train Loss: 0.1938, Train Acc: 0.9656 | Val Loss: 0.1719, Val Acc: 0.9744
# Batch 20, Loss: 0.1364
# Batch 40, Loss: 0.1828
# Batch 60, Loss: 0.2899
# Epoch: 29 - Train Loss: 0.2005, Train Acc: 0.9631 | Val Loss: 0.1750, Val Acc: 0.9791
# Batch 20, Loss: 0.2061
# Batch 40, Loss: 0.1705
# Batch 60, Loss: 0.1898
# Epoch: 30 - Train Loss: 0.1895, Train Acc: 0.9711 | Val Loss: 0.1690, Val Acc: 0.9767
# Batch 20, Loss: 0.2158
# Batch 40, Loss: 0.1680
# Batch 60, Loss: 0.1542
# Epoch: 31 - Train Loss: 0.1915, Train Acc: 0.9681 | Val Loss: 0.1724, Val Acc: 0.9791
# Early stopping at epoch 31 (No improvement for 6 epochs)
#
# ===== Run 3 =====
#
# Batch 20, Loss: 0.1966
# Batch 40, Loss: 0.3564
# Batch 60, Loss: 0.3477
# Epoch: 1 - Train Loss: 0.3645, Train Acc: 0.8665 | Val Loss: 0.2740, Val Acc: 0.9093
# Best model saved at epoch 1
# Batch 20, Loss: 0.3164
# Batch 40, Loss: 0.2974
# Batch 60, Loss: 0.3113
# Epoch: 2 - Train Loss: 0.2719, Train Acc: 0.9133 | Val Loss: 0.2365, Val Acc: 0.9372
# Best model saved at epoch 2
# Batch 20, Loss: 0.4143
# Batch 40, Loss: 0.2679
# Batch 60, Loss: 0.2555
# Epoch: 3 - Train Loss: 0.2541, Train Acc: 0.9268 | Val Loss: 0.2173, Val Acc: 0.9535
# Best model saved at epoch 3
# Batch 20, Loss: 0.2312
# Batch 40, Loss: 0.2937
# Batch 60, Loss: 0.1802
# Epoch: 4 - Train Loss: 0.2382, Train Acc: 0.9457 | Val Loss: 0.2054, Val Acc: 0.9558
# Best model saved at epoch 4
# Batch 20, Loss: 0.3170
# Batch 40, Loss: 0.3085
# Batch 60, Loss: 0.2135
# Epoch: 5 - Train Loss: 0.2245, Train Acc: 0.9497 | Val Loss: 0.1983, Val Acc: 0.9605
# Best model saved at epoch 5
# Batch 20, Loss: 0.2466
# Batch 40, Loss: 0.2132
# Batch 60, Loss: 0.2152
# Epoch: 6 - Train Loss: 0.2239, Train Acc: 0.9512 | Val Loss: 0.1945, Val Acc: 0.9605
# Best model saved at epoch 6
# Batch 20, Loss: 0.2386
# Batch 40, Loss: 0.1602
# Batch 60, Loss: 0.1668
# Epoch: 7 - Train Loss: 0.2187, Train Acc: 0.9522 | Val Loss: 0.1889, Val Acc: 0.9628
# Best model saved at epoch 7
# Batch 20, Loss: 0.2252
# Batch 40, Loss: 0.1860
# Batch 60, Loss: 0.1844
# Epoch: 8 - Train Loss: 0.2130, Train Acc: 0.9582 | Val Loss: 0.1950, Val Acc: 0.9651
# Batch 20, Loss: 0.2247
# Batch 40, Loss: 0.1907
# Batch 60, Loss: 0.1573
# Epoch: 9 - Train Loss: 0.2080, Train Acc: 0.9602 | Val Loss: 0.1857, Val Acc: 0.9698
# Best model saved at epoch 9
# Batch 20, Loss: 0.1993
# Batch 40, Loss: 0.2507
# Batch 60, Loss: 0.2019
# Epoch: 10 - Train Loss: 0.2114, Train Acc: 0.9582 | Val Loss: 0.1798, Val Acc: 0.9721
# Best model saved at epoch 10
# Batch 20, Loss: 0.2168
# Batch 40, Loss: 0.1699
# Batch 60, Loss: 0.2014
# Epoch: 11 - Train Loss: 0.2078, Train Acc: 0.9622 | Val Loss: 0.1773, Val Acc: 0.9791
# Best model saved at epoch 11
# Batch 20, Loss: 0.1672
# Batch 40, Loss: 0.2963
# Batch 60, Loss: 0.1757
# Epoch: 12 - Train Loss: 0.2072, Train Acc: 0.9602 | Val Loss: 0.1822, Val Acc: 0.9721
# Batch 20, Loss: 0.2028
# Batch 40, Loss: 0.2001
# Batch 60, Loss: 0.1848
# Epoch: 13 - Train Loss: 0.1990, Train Acc: 0.9671 | Val Loss: 0.1720, Val Acc: 0.9721
# Best model saved at epoch 13
# Batch 20, Loss: 0.1698
# Batch 40, Loss: 0.1295
# Batch 60, Loss: 0.2519
# Epoch: 14 - Train Loss: 0.2008, Train Acc: 0.9651 | Val Loss: 0.1699, Val Acc: 0.9791
# Best model saved at epoch 14
# Batch 20, Loss: 0.1718
# Batch 40, Loss: 0.1609
# Batch 60, Loss: 0.2471
# Epoch: 15 - Train Loss: 0.2042, Train Acc: 0.9592 | Val Loss: 0.1719, Val Acc: 0.9721
# Batch 20, Loss: 0.1527
# Batch 40, Loss: 0.2022
# Batch 60, Loss: 0.1795
# Epoch: 16 - Train Loss: 0.1993, Train Acc: 0.9631 | Val Loss: 0.1727, Val Acc: 0.9744
# Batch 20, Loss: 0.2104
# Batch 40, Loss: 0.2229
# Batch 60, Loss: 0.2273
# Epoch: 17 - Train Loss: 0.2006, Train Acc: 0.9661 | Val Loss: 0.1694, Val Acc: 0.9814
# Batch 20, Loss: 0.1715
# Batch 40, Loss: 0.1877
# Batch 60, Loss: 0.1538
# Epoch: 18 - Train Loss: 0.2046, Train Acc: 0.9656 | Val Loss: 0.1791, Val Acc: 0.9721
# Batch 20, Loss: 0.1693
# Batch 40, Loss: 0.2251
# Batch 60, Loss: 0.2468
# Epoch: 19 - Train Loss: 0.1949, Train Acc: 0.9666 | Val Loss: 0.1760, Val Acc: 0.9721
# Batch 20, Loss: 0.3094
# Batch 40, Loss: 0.2047
# Batch 60, Loss: 0.1707
# Epoch: 20 - Train Loss: 0.1971, Train Acc: 0.9656 | Val Loss: 0.1677, Val Acc: 0.9767
# Best model saved at epoch 20
# Batch 20, Loss: 0.1853
# Batch 40, Loss: 0.2364
# Batch 60, Loss: 0.1956
# Epoch: 21 - Train Loss: 0.1938, Train Acc: 0.9656 | Val Loss: 0.1759, Val Acc: 0.9721
# Batch 20, Loss: 0.1928
# Batch 40, Loss: 0.1816
# Batch 60, Loss: 0.1724
# Epoch: 22 - Train Loss: 0.1963, Train Acc: 0.9671 | Val Loss: 0.1710, Val Acc: 0.9721
# Batch 20, Loss: 0.1625
# Batch 40, Loss: 0.1555
# Batch 60, Loss: 0.1734
# Epoch: 23 - Train Loss: 0.1917, Train Acc: 0.9686 | Val Loss: 0.1657, Val Acc: 0.9814
# Best model saved at epoch 23
# Batch 20, Loss: 0.2465
# Batch 40, Loss: 0.1914
# Batch 60, Loss: 0.1624
# Epoch: 24 - Train Loss: 0.1967, Train Acc: 0.9681 | Val Loss: 0.1665, Val Acc: 0.9744
# Batch 20, Loss: 0.1692
# Batch 40, Loss: 0.2197
# Batch 60, Loss: 0.1726
# Epoch: 25 - Train Loss: 0.1896, Train Acc: 0.9706 | Val Loss: 0.1710, Val Acc: 0.9744
# Batch 20, Loss: 0.1494
# Batch 40, Loss: 0.1644
# Batch 60, Loss: 0.2032
# Epoch: 26 - Train Loss: 0.1947, Train Acc: 0.9681 | Val Loss: 0.1766, Val Acc: 0.9721
# Batch 20, Loss: 0.1437
# Batch 40, Loss: 0.1584
# Batch 60, Loss: 0.1942
# Epoch: 27 - Train Loss: 0.1952, Train Acc: 0.9671 | Val Loss: 0.1686, Val Acc: 0.9767
# Batch 20, Loss: 0.1466
# Batch 40, Loss: 0.1435
# Batch 60, Loss: 0.2196
# Epoch: 28 - Train Loss: 0.1919, Train Acc: 0.9711 | Val Loss: 0.1682, Val Acc: 0.9767
# Batch 20, Loss: 0.2012
# Batch 40, Loss: 0.1542
# Batch 60, Loss: 0.2019
# Epoch: 29 - Train Loss: 0.1943, Train Acc: 0.9701 | Val Loss: 0.1654, Val Acc: 0.9791
# Early stopping at epoch 29 (No improvement for 6 epochs)
#
# Duration: 924 seconds
#
# ===== Final Average Results ======
#
# Train Accuracy: 0.9678 +- 0.0012
# Valid Accuracy: 0.9814 +- 0.0000
# Train Loss: 0.1907 +- 0.0008
# Valid Loss: 0.1661 +- 0.0005
# n\Best overall model was from run 3 with val loss 0.1657
#
# saved to: base_Vit_B_16_new_extension/best_vit_extension_overall.pth

# %%
# visulize train and valid loss
import matplotlib.pyplot as plt
import numpy as np

# %%
max_len = max(len(run) for run in train_accuracies_all)

# %%
def pad_to_max(arr_list, max_len):
    return np.array([np.pad(run, (0, max_len - len(run)), constant_values=np.nan) for run in arr_list])

train_accuracies_pad = pad_to_max(train_accuracies_all, max_len)
valid_accuracies_pad = pad_to_max(valid_accuracies_all, max_len)
train_losses_pad = pad_to_max(train_losses_all, max_len)
valid_losses_pad = pad_to_max(valid_losses_all, max_len)

# %%
epochs = list(range(1, max_len + 1))
mean_train_acc = np.nanmean(train_accuracies_pad, axis=0)
std_train_acc = np.nanstd(train_accuracies_pad, axis=0)

mean_valid_acc = np.nanmean(valid_accuracies_pad, axis=0)
std_valid_acc = np.nanstd(valid_accuracies_pad, axis=0)


plt.figure(figsize = (8,5))
plt.plot(epochs, mean_train_acc, label='Train Accuracy', color = 'blue')
plt.fill_between(epochs, mean_train_acc - std_train_acc, mean_train_acc + std_train_acc, alpha = 0.1, color = 'blue')

plt.plot(epochs, mean_valid_acc, label='Valid Accuracy', color = 'orange')
plt.fill_between(epochs, mean_valid_acc - std_valid_acc, mean_valid_acc + std_valid_acc, alpha = 0.1, color = 'orange')

plt.title('')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
def pad_to_max(loss_list, max_len):
    return np.array([np.pad(run, (0, max_len - len(run)), constant_values=np.nan) for run in loss_list])

#train_losses_pad = pad_to_max(train_losses_all, max_len)
#valid_losses_pad = pad_to_max(valid_losses_all, max_len)
train_losses_pad = pad_to_max(train_losses_all, max_len)
valid_losses_pad = pad_to_max(valid_losses_all, max_len)

# %%
epochs = list(range(1, max_len + 1))
mean_train_loss = np.nanmean(train_losses_pad, axis=0)
std_train_loss = np.nanstd(train_losses_pad, axis=0)

mean_valid_loss = np.nanmean(valid_losses_pad, axis=0)
std_valid_loss = np.nanstd(valid_losses_pad,axis=0)

epochs = list(range(1, len(mean_train_loss)+1))

plt.figure(figsize = (8,5))
plt.plot(epochs, mean_train_loss, label='Train Loss', color = 'blue')
plt.fill_between(epochs, mean_train_loss - std_train_loss, mean_train_loss + std_train_loss, alpha = 0.1, color = 'blue')

plt.plot(epochs, mean_valid_loss, label='Valid Loss', color = 'orange')
plt.fill_between(epochs, mean_valid_loss - std_valid_loss, mean_valid_loss + std_valid_loss, alpha = 0.1, color = 'orange')

plt.title('')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
model_dir_extension = os.path.join(PROJECT_ROOT, 'base_Vit_B_16_new_extension')
model_filename_extension = 'best_vit_extension_overall.pth'
model_path_extension = os.path.join(model_dir_extension, model_filename_extension)

# %%
model.load_state_dict(torch.load(model_path_extension))
model  = model.to(device)
model.eval()
# Out:
# VisionTransformer(
#   (conv_proj): Conv2d(3, 768, kernel_size=(16, 16), stride=(16, 16))
#   (encoder): Encoder(
#     (dropout): Dropout(p=0.0, inplace=False)
#     (layers): Sequential(
#       (encoder_layer_0): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_1): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_2): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_3): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_4): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_5): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_6): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_7): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_8): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_9): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_10): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_11): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (ln): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#   )
#   (heads): Sequential(
#     (0): Dropout(p=0.4, inplace=False)
#     (1): Linear(in_features=768, out_features=2, bias=True)
#   )
# )

# %%
import seaborn as sns
all_preds = []
all_labels = []
with torch.no_grad():
    for images, labels in valid_loader:
        images = images.to('cuda')
        labels = labels.to('cuda')

        outputs = model(images)
        _, preds = torch.max(outputs,1)

        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

# %%
print("classification_report:\n")
print(classification_report(all_labels, all_preds))
# Out:
# classification_report:
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.90      0.93        59
#            1       0.98      0.99      0.99       371
#
#     accuracy                           0.98       430
#    macro avg       0.97      0.95      0.96       430
# weighted avg       0.98      0.98      0.98       430

# %%
# confusion matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(all_labels, all_preds)
plt.figure(figsize=(6,4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Non-Tumor', 'Tumor'],
            yticklabels=['Non-Tumor','Tumor'])
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('')
plt.tight_layout()
plt.show()
