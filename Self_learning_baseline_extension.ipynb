# %%
import os 
os.environ["CUDA_VISIBLE_DEVICES"] = "7"

# %%
import torch
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
print(torch.cuda.get_device_name(0))
# Out:
# NVIDIA RTX A6000

# %%
import os
import json
import torch
import torchvision.models as models
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F
from torch import nn, optim
from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder
from torchvision import datasets, transforms, models # add models to the list
from sklearn.metrics import classification_report
from torch.utils.data import Dataset
from PIL import Image
import time
from tqdm import tqdm
import numpy as np
import random
from torchvision.models import resnet18, ResNet18_Weights
from torch.optim.lr_scheduler import ReduceLROnPlateau

# %%
PROJECT_ROOT = os.getcwd()

# %%
train_path = PROJECT_ROOT+'/train/'
validation_path = PROJECT_ROOT+ '/validation/'

# %%
from glob import glob
class SimCLRDataset(Dataset):
    def __init__(self, data_path, transform=None):
        
        self.samples = []
        self.label_map = {
            'no_tumor': 0,
            'tumor': 1
            }
        for label_name, label_value in self.label_map.items():
            folder_path = os.path.join(data_path, label_name)
            image_paths = glob(os.path.join(folder_path, '*'))

            for image_path in image_paths:
                self.samples.append((
                    image_path, label_value
                    ))   
            self.transform = transform
            
    def __len__(self):
        return len(self.samples)
    def __getitem__(self, idx):
        image_path, label = self.samples[idx]
        image = Image.open(image_path).convert('RGB')
        xi, xj = self.transform(image)
        return xi, xj

# %%
# transformation for SimCLR
from torchvision import transforms
class TwoCropTransform:
    def __init__(self,base_transform):
        self.base_transform = base_transform
    def __call__(self, x):
        return self.base_transform(x), self.base_transform(x)

simclr_transform = TwoCropTransform(transforms.Compose([
        transforms.RandomAffine(degrees=0, shear=5, scale=(0.95,1.05)),
        transforms.RandomRotation(3),      
        transforms.RandomHorizontalFlip(p=0.5),  # reverse 50% of images
        transforms.RandomVerticalFlip(p=0.3),  # reverse 30% of images
        transforms.GaussianBlur(3, sigma=(0.1, 1.0)),
        transforms.Resize(224),             # resize shortest side to 224 pixels
        transforms.CenterCrop(224),         # crop longest side to 224 pixels at center
        transforms.ToTensor(),
        transforms.Normalize([0.5],[0.5])
    ]))

# SimCLR model
class SimCLR(nn.Module):
    def __init__(self, projection_dim=128):
        super().__init__()
        self.encoder = models.resnet18(weights=ResNet18_Weights.DEFAULT) 
        self.encoder.fc = nn.Identity()
        in_features = 512
        self.projector = nn.Sequential(
            nn.Linear(in_features, 512),
            nn.ReLU(),
            nn.Linear(512, projection_dim)
        )
    def forward(self, x):
        h = self.encoder(x)
        z = self.projector(h)
        return z

# %%
class NTXentLoss(nn.Module):
    def __init__(self, temperature = 0.3):
        super(NTXentLoss, self).__init__()
        self.temperature = temperature
        self.cos_sim = nn.CosineSimilarity(dim=2)
        
    def forward(self, zis, zjs):
        batch_size = zis.size(0)
        reps = torch.cat([zis, zjs], dim=0)
        sim_matrix = self.cos_sim(reps.unsqueeze(1), reps.unsqueeze(0))
        
        labels = torch.cat([torch.arange(batch_size) for _ in range(2)], dim=0)
        labels = (labels.unsqueeze(0) == labels.unsqueeze(1)).float().to(zis.device)

        mask = torch.eye(labels.shape[0],dtype=torch.bool).to(zis.device)
        labels = labels[~mask].view(labels.shape[0], -1)
        sim_matrix = sim_matrix[~mask].view(sim_matrix.shape[0], -1)

        positives = sim_matrix[labels.bool()].view(labels.shape[0], -1)
        negatives = sim_matrix[~labels.bool()].view(sim_matrix.shape[0], -1)

        logits = torch.cat([positives, negatives], dim=1)
        labels = torch.zeros(logits.shape[0],dtype=torch.long).to(zis.device)
        return F.cross_entropy(logits / self.temperature, labels)

# %%
import torch
import torch.nn as nn
from torchvision import models
from torchvision.models import resnet18, ResNet18_Weights
from torch.optim.lr_scheduler import ReduceLROnPlateau
import time
import random
import numpy as np

def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
#entry point
def run_simclr_training(data_path, batch_size, epochs=100, patience=6, min_delta=1e-4):
    set_seed(42)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    dataset = SimCLRDataset(train_path, simclr_transform)
    dataloader = DataLoader(dataset, batch_size=128, shuffle=True, drop_last=True, num_workers=4)

    model = SimCLR().to(device)
    
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-4, weight_decay = 1e-5)
    criterion = NTXentLoss(temperature=0.3)
    scheduler = ReduceLROnPlateau(optimizer, mode = 'min', factor =0.5, patience=3, threshold=0.001)
    
    #scheduler = CosineAnnealingLR(optimizer, T_max =100, eta_min=1e-6)
# early stopping
    best_loss = float('inf')
    patience_counter = 0
    start_time = time.time()

    for epoch in range(epochs):
        total_loss = 0
        for xi, xj in dataloader:
            xi, xj = xi.to(device), xj.to(device)
            zi = model(xi)
            zj = model(xj)

            loss = criterion(zi, zj)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            total_loss += loss.item()
        avg_loss = total_loss / len(dataloader)
        print(f"SimCLR pretraining - Epoch [{epoch+1}/{epochs}] Loss: {avg_loss:.4f}")

        if avg_loss < best_loss - min_delta:
            best_loss = avg_loss
            patience_counter = 0
        else:
            patience_counter += 1
        
        # stop training if patience limit is exceed
        if patience_counter >= patience:
            print(f"Early stopping triggered at epoch {epoch+1}. No improvement for {patience} epoches.")
            break
        #scheduler.step(avg_loss)
 
    torch.save(model.encoder.state_dict(), 'simclr_encoder_extension.pth')
    duration = time.time() - start_time
    print(f'\nDuration: {duration:.0f} seconds') # Print time elapsed

    return model.encoder
   
# define the linear evaluation model
class LinearClassifier(nn.Module):
    def __init__(self, encoder, feature_dim, num_classes):
        super(LinearClassifier, self).__init__()
        self.encoder = encoder
        for param in self.encoder.parameters():
            param.requires_grad = False
        self.classifier = nn.Linear(feature_dim, num_classes)
    def forward(self, x):
        with torch.no_grad():
            h = self.encoder(x)
        return self.classifier(h)

# %%
train_transform = transforms.Compose([
        transforms.RandomAffine(degrees=0, shear=5, scale=(0.95,1.05)),
        transforms.RandomRotation(3),      
        transforms.RandomHorizontalFlip(p=0.5),  # reverse 50% of images
        transforms.RandomVerticalFlip(p=0.3),  # reverse 30% of images
        transforms.GaussianBlur(3, sigma=(0.1, 1.0)),
        transforms.Resize(224),             # resize shortest side to 224 pixels
        transforms.CenterCrop(224),         # crop longest side to 224 pixels at center
        transforms.ToTensor(),
        transforms.Normalize([0.5],[0.5])
    ])


valid_transform = transforms.Compose([
        transforms.Resize(224),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.5],[0.5])
    ])

# %%
class TumorDataset(Dataset):
    def __init__(self, data_path, transform=None):
        
        self.samples = []
        self.label_map = {
            'no_tumor': 0,
            'tumor': 1
            }
        for label_name, label_value in self.label_map.items():
            folder_path = os.path.join(data_path, label_name)
            image_paths = glob(os.path.join(folder_path, '*'))

            for image_path in image_paths:
                self.samples.append((
                    image_path, label_value
                    ))   
            self.transform = transform

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        image_path, label = self.samples[idx]
        image = Image.open(image_path).convert('RGB')
        if self.transform:
            image = self.transform(image)
        return image, label

# %%
# SimCLR pretraining
encoder = run_simclr_training(
    data_path = train_path,
    batch_size=128,
    epochs=100,
    patience=6,
    min_delta=1e-4
    )
# Out:
# SimCLR pretraining - Epoch [1/100] Loss: 3.7070
# SimCLR pretraining - Epoch [2/100] Loss: 3.0147
# SimCLR pretraining - Epoch [3/100] Loss: 2.8454
# SimCLR pretraining - Epoch [4/100] Loss: 2.7463
# SimCLR pretraining - Epoch [5/100] Loss: 2.6840
# SimCLR pretraining - Epoch [6/100] Loss: 2.6406
# SimCLR pretraining - Epoch [7/100] Loss: 2.6085
# SimCLR pretraining - Epoch [8/100] Loss: 2.5817
# SimCLR pretraining - Epoch [9/100] Loss: 2.5574
# SimCLR pretraining - Epoch [10/100] Loss: 2.5440
# SimCLR pretraining - Epoch [11/100] Loss: 2.5299
# SimCLR pretraining - Epoch [12/100] Loss: 2.5183
# SimCLR pretraining - Epoch [13/100] Loss: 2.5060
# SimCLR pretraining - Epoch [14/100] Loss: 2.4979
# SimCLR pretraining - Epoch [15/100] Loss: 2.4888
# SimCLR pretraining - Epoch [16/100] Loss: 2.4795
# SimCLR pretraining - Epoch [17/100] Loss: 2.4743
# SimCLR pretraining - Epoch [18/100] Loss: 2.4663
# SimCLR pretraining - Epoch [19/100] Loss: 2.4627
# SimCLR pretraining - Epoch [20/100] Loss: 2.4580
# SimCLR pretraining - Epoch [21/100] Loss: 2.4550
# SimCLR pretraining - Epoch [22/100] Loss: 2.4525
# SimCLR pretraining - Epoch [23/100] Loss: 2.4495
# SimCLR pretraining - Epoch [24/100] Loss: 2.4470
# SimCLR pretraining - Epoch [25/100] Loss: 2.4405
# SimCLR pretraining - Epoch [26/100] Loss: 2.4413
# SimCLR pretraining - Epoch [27/100] Loss: 2.4383
# SimCLR pretraining - Epoch [28/100] Loss: 2.4313
# SimCLR pretraining - Epoch [29/100] Loss: 2.4327
# SimCLR pretraining - Epoch [30/100] Loss: 2.4314
# SimCLR pretraining - Epoch [31/100] Loss: 2.4262
# SimCLR pretraining - Epoch [32/100] Loss: 2.4245
# SimCLR pretraining - Epoch [33/100] Loss: 2.4234
# SimCLR pretraining - Epoch [34/100] Loss: 2.4188
# SimCLR pretraining - Epoch [35/100] Loss: 2.4201
# SimCLR pretraining - Epoch [36/100] Loss: 2.4160
# SimCLR pretraining - Epoch [37/100] Loss: 2.4161
# SimCLR pretraining - Epoch [38/100] Loss: 2.4129
# SimCLR pretraining - Epoch [39/100] Loss: 2.4111
# SimCLR pretraining - Epoch [40/100] Loss: 2.4098
# SimCLR pretraining - Epoch [41/100] Loss: 2.4106
# SimCLR pretraining - Epoch [42/100] Loss: 2.4071
# SimCLR pretraining - Epoch [43/100] Loss: 2.4047
# SimCLR pretraining - Epoch [44/100] Loss: 2.4068
# SimCLR pretraining - Epoch [45/100] Loss: 2.4047
# SimCLR pretraining - Epoch [46/100] Loss: 2.4060
# SimCLR pretraining - Epoch [47/100] Loss: 2.4044
# SimCLR pretraining - Epoch [48/100] Loss: 2.4032
# SimCLR pretraining - Epoch [49/100] Loss: 2.3999
# SimCLR pretraining - Epoch [50/100] Loss: 2.4004
# SimCLR pretraining - Epoch [51/100] Loss: 2.3981
# SimCLR pretraining - Epoch [52/100] Loss: 2.4020
# SimCLR pretraining - Epoch [53/100] Loss: 2.3973
# SimCLR pretraining - Epoch [54/100] Loss: 2.3959
# SimCLR pretraining - Epoch [55/100] Loss: 2.3943
# SimCLR pretraining - Epoch [56/100] Loss: 2.3940
# SimCLR pretraining - Epoch [57/100] Loss: 2.3949
# SimCLR pretraining - Epoch [58/100] Loss: 2.3954
# SimCLR pretraining - Epoch [59/100] Loss: 2.3960
# SimCLR pretraining - Epoch [60/100] Loss: 2.3919
# SimCLR pretraining - Epoch [61/100] Loss: 2.3944
# SimCLR pretraining - Epoch [62/100] Loss: 2.3913
# SimCLR pretraining - Epoch [63/100] Loss: 2.3902
# SimCLR pretraining - Epoch [64/100] Loss: 2.3959
# SimCLR pretraining - Epoch [65/100] Loss: 2.3898
# SimCLR pretraining - Epoch [66/100] Loss: 2.3900
# SimCLR pretraining - Epoch [67/100] Loss: 2.3875
# SimCLR pretraining - Epoch [68/100] Loss: 2.3873
# SimCLR pretraining - Epoch [69/100] Loss: 2.3872
# SimCLR pretraining - Epoch [70/100] Loss: 2.3874
# SimCLR pretraining - Epoch [71/100] Loss: 2.3875
# SimCLR pretraining - Epoch [72/100] Loss: 2.3838
# SimCLR pretraining - Epoch [73/100] Loss: 2.3858
# SimCLR pretraining - Epoch [74/100] Loss: 2.3846
# SimCLR pretraining - Epoch [75/100] Loss: 2.3855
# SimCLR pretraining - Epoch [76/100] Loss: 2.3848
# SimCLR pretraining - Epoch [77/100] Loss: 2.3832
# SimCLR pretraining - Epoch [78/100] Loss: 2.3842
# SimCLR pretraining - Epoch [79/100] Loss: 2.3833
# SimCLR pretraining - Epoch [80/100] Loss: 2.3839
# SimCLR pretraining - Epoch [81/100] Loss: 2.3828
# SimCLR pretraining - Epoch [82/100] Loss: 2.3819
# SimCLR pretraining - Epoch [83/100] Loss: 2.3820
# SimCLR pretraining - Epoch [84/100] Loss: 2.3805
# SimCLR pretraining - Epoch [85/100] Loss: 2.3797
# SimCLR pretraining - Epoch [86/100] Loss: 2.3816
# SimCLR pretraining - Epoch [87/100] Loss: 2.3787
# SimCLR pretraining - Epoch [88/100] Loss: 2.3798
# SimCLR pretraining - Epoch [89/100] Loss: 2.3790
# SimCLR pretraining - Epoch [90/100] Loss: 2.3779
# SimCLR pretraining - Epoch [91/100] Loss: 2.3785
# SimCLR pretraining - Epoch [92/100] Loss: 2.3791
# SimCLR pretraining - Epoch [93/100] Loss: 2.3755
# SimCLR pretraining - Epoch [94/100] Loss: 2.3772
# SimCLR pretraining - Epoch [95/100] Loss: 2.3771
# SimCLR pretraining - Epoch [96/100] Loss: 2.3756
# SimCLR pretraining - Epoch [97/100] Loss: 2.3767
# SimCLR pretraining - Epoch [98/100] Loss: 2.3774
# SimCLR pretraining - Epoch [99/100] Loss: 2.3766
# Early stopping triggered at epoch 99. No improvement for 6 epoches.
#
# Duration: 1473 seconds

# %%
encoder.eval()
encoder=encoder.to(device)

# %%
# Load datasets for linear evaluation
train_data = TumorDataset(
    data_path = train_path,
    transform=train_transform
)
valid_data = TumorDataset(
    data_path = validation_path,
    transform=valid_transform
)

train_loader = DataLoader(train_data, batch_size=32, shuffle=True)
valid_loader = DataLoader(valid_data, batch_size=32, shuffle=True)

# %%
# start to load pre-trained ResNet18 model and fine-tune
import os
import time
from tqdm import tqdm
import numpy as np
import random
import shutil

save_dir_simclr_extension = os.path.join(PROJECT_ROOT, 'base_simclr_new_extension')
os.makedirs(save_dir_simclr_extension,exist_ok = True)
num_runs = 3
train_accuracies_all = []
valid_accuracies_all = []
train_losses_all = []
valid_losses_all = []

all_train_acc = []
all_val_acc =[]
all_train_loss = []
all_val_loss =[]
# track the best val loss of each run 
best_val_losses_all = []



for run in range(num_runs):
    print(f"\n===== Run {run+1} =====\n")
    torch.manual_seed(42 + run)
    torch.cuda.manual_seed(42 + run)
    np.random.seed(42 + run)
    random.seed(42 + run)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

    train_loader = DataLoader(train_data, batch_size = 32, shuffle=True)
    valid_loader = DataLoader(valid_data, batch_size = 32, shuffle=True)

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    encoder.eval()
    model = LinearClassifier(encoder, feature_dim=512, num_classes=2).to(device)
    criterion = nn.CrossEntropyLoss(label_smoothing=0.05)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-4, weight_decay=1e-5)
    scheduler = ReduceLROnPlateau(optimizer, mode = 'min', factor =0.5, patience=3, threshold=0.001)
    best_val_acc = 0
    best_model_path_extension = os.path.join(save_dir_simclr_extension, f"best_simclr_extension_run{run+1 }.pth")
    
   

    # train the model with early stopping

    epochs = 35 # Keep the high epoch count, early stopping will decide when to stop
    patience =4 # Stop training if validation loss does not improve for 'patience' epochs
    min_delta = 0.001 # Minimum change to qualify as an improvement
    best_val_loss = float('inf') # Track best validation loss
    counter = 0 # Track consecutive epochs without improvement
    best_model_path_extension = os.path.join(save_dir_simclr_extension, f'best_simclr_extension_run{run+1}.pth')

    train_losses = []
    valid_losses= []
    train_accuracies = []
    valid_accuracies= []

    # track best epoch metircs
    val_accuracy_at_best_loss = None
    train_accuracy_at_best_loss = None
    train_loss_at_best_loss = None
    val_loss_at_best_loss = None

    start_time = time.time()

    for epoch in range(epochs):
        model.train()
        epoch_train_loss = 0.0
        train_correct = 0
        total_train = 0
    
    # Run the training batches
        for b, (X_train, y_train) in enumerate(train_loader):
            b+=1
            X_train, y_train = X_train.to('cuda'), y_train.to('cuda')
        
            # forward pass
            outputs = model(X_train)
            loss = criterion(outputs, y_train)

            # backward propagation 
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            # track loos and accuracy
            epoch_train_loss += loss.item()
            preds = outputs.argmax(dim=1)
            train_correct += (preds == y_train).sum().item()
            total_train += y_train.size(0)

            # optional debug
            if b%20 == 0:
                print(f"Batch {b}, Loss: {loss.item():.4f}")

        avg_train_loss = epoch_train_loss / len(train_loader)
        train_accuracy = train_correct / total_train

        train_losses.append(avg_train_loss)
        train_accuracies.append(train_accuracy)

        # validation part
        model.eval()
        epoch_val_loss = 0.0
        val_correct = 0
        total_val = 0

        with torch.no_grad():
            for X_val, y_val in valid_loader:
                X_val, y_val = X_val.to('cuda'), y_val.to('cuda')

                outputs = model(X_val)
                loss = criterion(outputs, y_val)

                epoch_val_loss += loss.item()
                preds = outputs.argmax(dim=1)
                val_correct += (preds == y_val).sum().item()
                total_val += y_val.size(0)
       
           
        avg_val_loss = epoch_val_loss / len(valid_loader)
        val_accuracy = val_correct / total_val

        valid_losses.append(avg_val_loss)
        valid_accuracies.append(val_accuracy)

  

        print(f"Epoch: {epoch+1} - Train Loss: {avg_train_loss:.4f}, Train Acc: {train_accuracy:.4g} | "
              f"Val Loss: {avg_val_loss:.4f}, Val Acc: {val_accuracy:.4f}")
        scheduler.step(avg_train_loss)
      
        
        # **Early stopping logic**
        if avg_val_loss < best_val_loss - min_delta:
            best_val_loss = avg_val_loss # Update best loss
            val_accuracy_at_best_loss = val_accuracy
            train_accuracy_at_best_loss = train_accuracy
            train_loss_at_best_loss = avg_train_loss
            val_loss_at_best_loss = avg_val_loss

            counter = 0 # Reset counter
             # save the best model for this run
            torch.save(model.state_dict(), best_model_path_extension)
            print(f"Best model saved at epoch {epoch+1}")
       
        else:
            counter += 1 # Increase counter
            if counter >= patience: # Stop if no improvement for 'patience' epochs
                print(f"Early stopping at epoch {epoch+1} (No improvement for {patience} epochs)")
                break
    #save metrics from each run
    all_train_acc.append(train_accuracy_at_best_loss)
    all_val_acc.append(val_accuracy_at_best_loss)
    all_train_loss.append(train_loss_at_best_loss)
    all_val_loss.append(val_loss_at_best_loss)   
    best_val_losses_all.append(best_val_loss)

    # save full per-epoch history
    train_accuracies_all.append(train_accuracies)
    valid_accuracies_all.append(valid_accuracies)
    train_losses_all.append(train_losses)
    valid_losses_all.append(valid_losses)

print(f'\nDuration: {time.time() - start_time:.0f} seconds') # Print time elapsed
# final results
print("\n===== Final Average Results ======\n")
print(f"Train Accuracy (best val loss): {np.mean(all_train_acc):.4f} +- {np.std(all_train_acc):.4f}")
print(f"Valid Accuracy: {np.mean(all_val_acc):.4f} +- {np.std(all_val_acc):.4f}")
print(f"Train Loss: {np.mean(all_train_loss):.4f} +- {np.std(all_train_loss):.4f}")
print(f"Valid Loss: {np.mean(all_val_loss):.4f} +- {np.std(all_val_loss):.4f}")

# save only the best model across runs
best_run_idx = np.argmin(best_val_losses_all)
best_model_path_extension = os.path.join(save_dir_simclr_extension, f"best_simclr_extension_run{best_run_idx + 1}.pth")
final_best_model_path_extension = os.path.join(save_dir_simclr_extension, 'best_simclr_extension_overall.pth')
shutil.copy(best_model_path_extension, final_best_model_path_extension)
print(f"n\Best overall model was from run {best_run_idx + 1} with val loss {best_val_losses_all[best_run_idx]:.4f}")
print(f"Saved as: {os.path.relpath(final_best_model_path_extension)}")
# Out:
# ===== Run 1 =====
#
# Batch 20, Loss: 0.5390
# Batch 40, Loss: 0.4282
# Batch 60, Loss: 0.4526
# Epoch: 1 - Train Loss: 0.4416, Train Acc: 0.8476 | Val Loss: 0.3843, Val Acc: 0.8651
# Best model saved at epoch 1
# Batch 20, Loss: 0.2771
# Batch 40, Loss: 0.2861
# Batch 60, Loss: 0.3044
# Epoch: 2 - Train Loss: 0.3531, Train Acc: 0.8695 | Val Loss: 0.3217, Val Acc: 0.8791
# Best model saved at epoch 2
# Batch 20, Loss: 0.3491
# Batch 40, Loss: 0.3043
# Batch 60, Loss: 0.2811
# Epoch: 3 - Train Loss: 0.3116, Train Acc: 0.8934 | Val Loss: 0.2939, Val Acc: 0.8907
# Best model saved at epoch 3
# Batch 20, Loss: 0.2866
# Batch 40, Loss: 0.2508
# Batch 60, Loss: 0.2682
# Epoch: 4 - Train Loss: 0.2869, Train Acc: 0.9084 | Val Loss: 0.2624, Val Acc: 0.9163
# Best model saved at epoch 4
# Batch 20, Loss: 0.2171
# Batch 40, Loss: 0.2312
# Batch 60, Loss: 0.2253
# Epoch: 5 - Train Loss: 0.2733, Train Acc: 0.9143 | Val Loss: 0.2452, Val Acc: 0.9233
# Best model saved at epoch 5
# Batch 20, Loss: 0.2609
# Batch 40, Loss: 0.2138
# Batch 60, Loss: 0.2165
# Epoch: 6 - Train Loss: 0.2598, Train Acc: 0.9238 | Val Loss: 0.2343, Val Acc: 0.9372
# Best model saved at epoch 6
# Batch 20, Loss: 0.2013
# Batch 40, Loss: 0.2501
# Batch 60, Loss: 0.3441
# Epoch: 7 - Train Loss: 0.2564, Train Acc: 0.9278 | Val Loss: 0.2316, Val Acc: 0.9326
# Best model saved at epoch 7
# Batch 20, Loss: 0.4573
# Batch 40, Loss: 0.2803
# Batch 60, Loss: 0.1759
# Epoch: 8 - Train Loss: 0.2532, Train Acc: 0.9268 | Val Loss: 0.2208, Val Acc: 0.9419
# Best model saved at epoch 8
# Batch 20, Loss: 0.1764
# Batch 40, Loss: 0.2299
# Batch 60, Loss: 0.3248
# Epoch: 9 - Train Loss: 0.2434, Train Acc: 0.9358 | Val Loss: 0.2152, Val Acc: 0.9465
# Best model saved at epoch 9
# Batch 20, Loss: 0.2284
# Batch 40, Loss: 0.2847
# Batch 60, Loss: 0.2347
# Epoch: 10 - Train Loss: 0.2345, Train Acc: 0.9432 | Val Loss: 0.2105, Val Acc: 0.9488
# Best model saved at epoch 10
# Batch 20, Loss: 0.2720
# Batch 40, Loss: 0.2490
# Batch 60, Loss: 0.1717
# Epoch: 11 - Train Loss: 0.2380, Train Acc: 0.9412 | Val Loss: 0.2037, Val Acc: 0.9535
# Best model saved at epoch 11
# Batch 20, Loss: 0.1707
# Batch 40, Loss: 0.2257
# Batch 60, Loss: 0.2611
# Epoch: 12 - Train Loss: 0.2349, Train Acc: 0.9407 | Val Loss: 0.2001, Val Acc: 0.9581
# Best model saved at epoch 12
# Batch 20, Loss: 0.2676
# Batch 40, Loss: 0.2342
# Batch 60, Loss: 0.2496
# Epoch: 13 - Train Loss: 0.2351, Train Acc: 0.9437 | Val Loss: 0.1954, Val Acc: 0.9605
# Best model saved at epoch 13
# Batch 20, Loss: 0.1866
# Batch 40, Loss: 0.1658
# Batch 60, Loss: 0.1930
# Epoch: 14 - Train Loss: 0.2257, Train Acc: 0.9487 | Val Loss: 0.2047, Val Acc: 0.9605
# Batch 20, Loss: 0.3246
# Batch 40, Loss: 0.2240
# Batch 60, Loss: 0.3003
# Epoch: 15 - Train Loss: 0.2236, Train Acc: 0.9492 | Val Loss: 0.1962, Val Acc: 0.9628
# Batch 20, Loss: 0.2775
# Batch 40, Loss: 0.2089
# Batch 60, Loss: 0.1658
# Epoch: 16 - Train Loss: 0.2204, Train Acc: 0.9522 | Val Loss: 0.1910, Val Acc: 0.9628
# Best model saved at epoch 16
# Batch 20, Loss: 0.3383
# Batch 40, Loss: 0.2243
# Batch 60, Loss: 0.1874
# Epoch: 17 - Train Loss: 0.2169, Train Acc: 0.9582 | Val Loss: 0.1878, Val Acc: 0.9674
# Best model saved at epoch 17
# Batch 20, Loss: 0.2196
# Batch 40, Loss: 0.2623
# Batch 60, Loss: 0.2219
# Epoch: 18 - Train Loss: 0.2167, Train Acc: 0.9542 | Val Loss: 0.1877, Val Acc: 0.9698
# Batch 20, Loss: 0.1398
# Batch 40, Loss: 0.2011
# Batch 60, Loss: 0.1672
# Epoch: 19 - Train Loss: 0.2155, Train Acc: 0.9567 | Val Loss: 0.1872, Val Acc: 0.9628
# Batch 20, Loss: 0.2224
# Batch 40, Loss: 0.2005
# Batch 60, Loss: 0.3234
# Epoch: 20 - Train Loss: 0.2126, Train Acc: 0.9572 | Val Loss: 0.1861, Val Acc: 0.9721
# Best model saved at epoch 20
# Batch 20, Loss: 0.2956
# Batch 40, Loss: 0.1762
# Batch 60, Loss: 0.2685
# Epoch: 21 - Train Loss: 0.2146, Train Acc: 0.9567 | Val Loss: 0.1860, Val Acc: 0.9674
# Batch 20, Loss: 0.2069
# Batch 40, Loss: 0.1761
# Batch 60, Loss: 0.2358
# Epoch: 22 - Train Loss: 0.2170, Train Acc: 0.9507 | Val Loss: 0.1879, Val Acc: 0.9721
# Batch 20, Loss: 0.1663
# Batch 40, Loss: 0.1883
# Batch 60, Loss: 0.1976
# Epoch: 23 - Train Loss: 0.2108, Train Acc: 0.9582 | Val Loss: 0.1834, Val Acc: 0.9674
# Best model saved at epoch 23
# Batch 20, Loss: 0.2420
# Batch 40, Loss: 0.1773
# Batch 60, Loss: 0.1720
# Epoch: 24 - Train Loss: 0.2080, Train Acc: 0.9562 | Val Loss: 0.1827, Val Acc: 0.9698
# Batch 20, Loss: 0.2497
# Batch 40, Loss: 0.1838
# Batch 60, Loss: 0.2022
# Epoch: 25 - Train Loss: 0.2062, Train Acc: 0.9577 | Val Loss: 0.1803, Val Acc: 0.9767
# Best model saved at epoch 25
# Batch 20, Loss: 0.3921
# Batch 40, Loss: 0.1851
# Batch 60, Loss: 0.1712
# Epoch: 26 - Train Loss: 0.2065, Train Acc: 0.9602 | Val Loss: 0.1796, Val Acc: 0.9744
# Batch 20, Loss: 0.2479
# Batch 40, Loss: 0.1851
# Batch 60, Loss: 0.1726
# Epoch: 27 - Train Loss: 0.2068, Train Acc: 0.9582 | Val Loss: 0.1783, Val Acc: 0.9767
# Best model saved at epoch 27
# Batch 20, Loss: 0.2002
# Batch 40, Loss: 0.1961
# Batch 60, Loss: 0.2317
# Epoch: 28 - Train Loss: 0.2050, Train Acc: 0.9661 | Val Loss: 0.1817, Val Acc: 0.9721
# Batch 20, Loss: 0.2653
# Batch 40, Loss: 0.1739
# Batch 60, Loss: 0.1482
# Epoch: 29 - Train Loss: 0.2023, Train Acc: 0.9646 | Val Loss: 0.1767, Val Acc: 0.9698
# Best model saved at epoch 29
# Batch 20, Loss: 0.2282
# Batch 40, Loss: 0.2351
# Batch 60, Loss: 0.2410
# Epoch: 30 - Train Loss: 0.2007, Train Acc: 0.9612 | Val Loss: 0.1802, Val Acc: 0.9721
# Batch 20, Loss: 0.2294
# Batch 40, Loss: 0.1650
# Batch 60, Loss: 0.1866
# Epoch: 31 - Train Loss: 0.2015, Train Acc: 0.9622 | Val Loss: 0.1768, Val Acc: 0.9791
# Batch 20, Loss: 0.2644
# Batch 40, Loss: 0.1976
# Batch 60, Loss: 0.1549
# Epoch: 32 - Train Loss: 0.1985, Train Acc: 0.9636 | Val Loss: 0.1747, Val Acc: 0.9767
# Best model saved at epoch 32
# Batch 20, Loss: 0.2020
# Batch 40, Loss: 0.1494
# Batch 60, Loss: 0.1824
# Epoch: 33 - Train Loss: 0.2044, Train Acc: 0.9567 | Val Loss: 0.1748, Val Acc: 0.9767
# Batch 20, Loss: 0.1832
# Batch 40, Loss: 0.1728
# Batch 60, Loss: 0.1499
# Epoch: 34 - Train Loss: 0.2011, Train Acc: 0.9607 | Val Loss: 0.1740, Val Acc: 0.9791
# Batch 20, Loss: 0.1699
# Batch 40, Loss: 0.1881
# Batch 60, Loss: 0.1617
# Epoch: 35 - Train Loss: 0.2046, Train Acc: 0.9582 | Val Loss: 0.1733, Val Acc: 0.9744
# Best model saved at epoch 35
#
# ===== Run 2 =====
#
# Batch 20, Loss: 0.5179
# Batch 40, Loss: 0.4251
# Batch 60, Loss: 0.3253
# Epoch: 1 - Train Loss: 0.5523, Train Acc: 0.7485 | Val Loss: 0.4230, Val Acc: 0.8628
# Best model saved at epoch 1
# Batch 20, Loss: 0.3151
# Batch 40, Loss: 0.2769
# Batch 60, Loss: 0.3520
# Epoch: 2 - Train Loss: 0.3865, Train Acc: 0.8635 | Val Loss: 0.3758, Val Acc: 0.8767
# Best model saved at epoch 2
# Batch 20, Loss: 0.2555
# Batch 40, Loss: 0.3809
# Batch 60, Loss: 0.2165
# Epoch: 3 - Train Loss: 0.3398, Train Acc: 0.8795 | Val Loss: 0.3402, Val Acc: 0.8698
# Best model saved at epoch 3
# Batch 20, Loss: 0.3388
# Batch 40, Loss: 0.3020
# Batch 60, Loss: 0.4179
# Epoch: 4 - Train Loss: 0.3178, Train Acc: 0.8845 | Val Loss: 0.3015, Val Acc: 0.8744
# Best model saved at epoch 4
# Batch 20, Loss: 0.2323
# Batch 40, Loss: 0.2535
# Batch 60, Loss: 0.4232
# Epoch: 5 - Train Loss: 0.2941, Train Acc: 0.8969 | Val Loss: 0.2794, Val Acc: 0.8837
# Best model saved at epoch 5
# Batch 20, Loss: 0.3241
# Batch 40, Loss: 0.4094
# Batch 60, Loss: 0.2567
# Epoch: 6 - Train Loss: 0.2876, Train Acc: 0.8979 | Val Loss: 0.2680, Val Acc: 0.8953
# Best model saved at epoch 6
# Batch 20, Loss: 0.3072
# Batch 40, Loss: 0.4211
# Batch 60, Loss: 0.4018
# Epoch: 7 - Train Loss: 0.2721, Train Acc: 0.9168 | Val Loss: 0.2528, Val Acc: 0.9047
# Best model saved at epoch 7
# Batch 20, Loss: 0.2458
# Batch 40, Loss: 0.3023
# Batch 60, Loss: 0.4312
# Epoch: 8 - Train Loss: 0.2664, Train Acc: 0.9238 | Val Loss: 0.2418, Val Acc: 0.9140
# Best model saved at epoch 8
# Batch 20, Loss: 0.3468
# Batch 40, Loss: 0.2411
# Batch 60, Loss: 0.3007
# Epoch: 9 - Train Loss: 0.2568, Train Acc: 0.9278 | Val Loss: 0.2339, Val Acc: 0.9279
# Best model saved at epoch 9
# Batch 20, Loss: 0.3173
# Batch 40, Loss: 0.2207
# Batch 60, Loss: 0.2014
# Epoch: 10 - Train Loss: 0.2561, Train Acc: 0.9328 | Val Loss: 0.2284, Val Acc: 0.9302
# Best model saved at epoch 10
# Batch 20, Loss: 0.2887
# Batch 40, Loss: 0.3276
# Batch 60, Loss: 0.4781
# Epoch: 11 - Train Loss: 0.2465, Train Acc: 0.9363 | Val Loss: 0.2324, Val Acc: 0.9372
# Batch 20, Loss: 0.1876
# Batch 40, Loss: 0.3698
# Batch 60, Loss: 0.1891
# Epoch: 12 - Train Loss: 0.2433, Train Acc: 0.9313 | Val Loss: 0.2177, Val Acc: 0.9372
# Best model saved at epoch 12
# Batch 20, Loss: 0.1711
# Batch 40, Loss: 0.3074
# Batch 60, Loss: 0.2795
# Epoch: 13 - Train Loss: 0.2395, Train Acc: 0.9373 | Val Loss: 0.2147, Val Acc: 0.9512
# Best model saved at epoch 13
# Batch 20, Loss: 0.2384
# Batch 40, Loss: 0.3637
# Batch 60, Loss: 0.2437
# Epoch: 14 - Train Loss: 0.2366, Train Acc: 0.9392 | Val Loss: 0.2146, Val Acc: 0.9558
# Batch 20, Loss: 0.2336
# Batch 40, Loss: 0.2285
# Batch 60, Loss: 0.1985
# Epoch: 15 - Train Loss: 0.2331, Train Acc: 0.9432 | Val Loss: 0.2077, Val Acc: 0.9535
# Best model saved at epoch 15
# Batch 20, Loss: 0.3136
# Batch 40, Loss: 0.2273
# Batch 60, Loss: 0.2355
# Epoch: 16 - Train Loss: 0.2282, Train Acc: 0.9467 | Val Loss: 0.2037, Val Acc: 0.9558
# Best model saved at epoch 16
# Batch 20, Loss: 0.2528
# Batch 40, Loss: 0.2471
# Batch 60, Loss: 0.2031
# Epoch: 17 - Train Loss: 0.2273, Train Acc: 0.9497 | Val Loss: 0.1999, Val Acc: 0.9535
# Best model saved at epoch 17
# Batch 20, Loss: 0.2620
# Batch 40, Loss: 0.1778
# Batch 60, Loss: 0.2237
# Epoch: 18 - Train Loss: 0.2234, Train Acc: 0.9472 | Val Loss: 0.2028, Val Acc: 0.9581
# Batch 20, Loss: 0.2441
# Batch 40, Loss: 0.2450
# Batch 60, Loss: 0.2047
# Epoch: 19 - Train Loss: 0.2249, Train Acc: 0.9492 | Val Loss: 0.2003, Val Acc: 0.9581
# Batch 20, Loss: 0.2690
# Batch 40, Loss: 0.2499
# Batch 60, Loss: 0.2703
# Epoch: 20 - Train Loss: 0.2235, Train Acc: 0.9537 | Val Loss: 0.1930, Val Acc: 0.9581
# Best model saved at epoch 20
# Batch 20, Loss: 0.2551
# Batch 40, Loss: 0.1853
# Batch 60, Loss: 0.1990
# Epoch: 21 - Train Loss: 0.2181, Train Acc: 0.9567 | Val Loss: 0.1918, Val Acc: 0.9581
# Best model saved at epoch 21
# Batch 20, Loss: 0.2592
# Batch 40, Loss: 0.1651
# Batch 60, Loss: 0.2984
# Epoch: 22 - Train Loss: 0.2175, Train Acc: 0.9517 | Val Loss: 0.1914, Val Acc: 0.9628
# Batch 20, Loss: 0.2563
# Batch 40, Loss: 0.2020
# Batch 60, Loss: 0.2182
# Epoch: 23 - Train Loss: 0.2175, Train Acc: 0.9517 | Val Loss: 0.1960, Val Acc: 0.9651
# Batch 20, Loss: 0.3344
# Batch 40, Loss: 0.2428
# Batch 60, Loss: 0.4518
# Epoch: 24 - Train Loss: 0.2193, Train Acc: 0.9517 | Val Loss: 0.1932, Val Acc: 0.9674
# Batch 20, Loss: 0.2723
# Batch 40, Loss: 0.2357
# Batch 60, Loss: 0.2859
# Epoch: 25 - Train Loss: 0.2123, Train Acc: 0.9572 | Val Loss: 0.1870, Val Acc: 0.9698
# Best model saved at epoch 25
# Batch 20, Loss: 0.1597
# Batch 40, Loss: 0.2623
# Batch 60, Loss: 0.2271
# Epoch: 26 - Train Loss: 0.2126, Train Acc: 0.9577 | Val Loss: 0.1857, Val Acc: 0.9698
# Best model saved at epoch 26
# Batch 20, Loss: 0.1799
# Batch 40, Loss: 0.1661
# Batch 60, Loss: 0.2149
# Epoch: 27 - Train Loss: 0.2110, Train Acc: 0.9552 | Val Loss: 0.1903, Val Acc: 0.9674
# Batch 20, Loss: 0.2522
# Batch 40, Loss: 0.1855
# Batch 60, Loss: 0.2219
# Epoch: 28 - Train Loss: 0.2078, Train Acc: 0.9602 | Val Loss: 0.1899, Val Acc: 0.9721
# Batch 20, Loss: 0.2032
# Batch 40, Loss: 0.1925
# Batch 60, Loss: 0.1885
# Epoch: 29 - Train Loss: 0.2091, Train Acc: 0.9552 | Val Loss: 0.1854, Val Acc: 0.9674
# Batch 20, Loss: 0.1639
# Batch 40, Loss: 0.1592
# Batch 60, Loss: 0.1545
# Epoch: 30 - Train Loss: 0.2069, Train Acc: 0.9607 | Val Loss: 0.1849, Val Acc: 0.9767
# Early stopping at epoch 30 (No improvement for 4 epochs)
#
# ===== Run 3 =====
#
# Batch 20, Loss: 0.5291
# Batch 40, Loss: 0.2640
# Batch 60, Loss: 0.4702
# Epoch: 1 - Train Loss: 0.5380, Train Acc: 0.7754 | Val Loss: 0.4140, Val Acc: 0.8628
# Best model saved at epoch 1
# Batch 20, Loss: 0.4381
# Batch 40, Loss: 0.5508
# Batch 60, Loss: 0.5103
# Epoch: 2 - Train Loss: 0.3998, Train Acc: 0.863 | Val Loss: 0.3482, Val Acc: 0.8651
# Best model saved at epoch 2
# Batch 20, Loss: 0.2177
# Batch 40, Loss: 0.3570
# Batch 60, Loss: 0.3091
# Epoch: 3 - Train Loss: 0.3474, Train Acc: 0.867 | Val Loss: 0.3069, Val Acc: 0.8744
# Best model saved at epoch 3
# Batch 20, Loss: 0.2722
# Batch 40, Loss: 0.2741
# Batch 60, Loss: 0.5441
# Epoch: 4 - Train Loss: 0.3151, Train Acc: 0.88 | Val Loss: 0.2761, Val Acc: 0.8977
# Best model saved at epoch 4
# Batch 20, Loss: 0.2294
# Batch 40, Loss: 0.3341
# Batch 60, Loss: 0.4053
# Epoch: 5 - Train Loss: 0.2905, Train Acc: 0.8989 | Val Loss: 0.2641, Val Acc: 0.9209
# Best model saved at epoch 5
# Batch 20, Loss: 0.3046
# Batch 40, Loss: 0.2580
# Batch 60, Loss: 0.3186
# Epoch: 6 - Train Loss: 0.2767, Train Acc: 0.9153 | Val Loss: 0.2526, Val Acc: 0.9279
# Best model saved at epoch 6
# Batch 20, Loss: 0.2426
# Batch 40, Loss: 0.2676
# Batch 60, Loss: 0.1936
# Epoch: 7 - Train Loss: 0.2678, Train Acc: 0.9173 | Val Loss: 0.2350, Val Acc: 0.9395
# Best model saved at epoch 7
# Batch 20, Loss: 0.2362
# Batch 40, Loss: 0.2422
# Batch 60, Loss: 0.2590
# Epoch: 8 - Train Loss: 0.2585, Train Acc: 0.9268 | Val Loss: 0.2318, Val Acc: 0.9395
# Best model saved at epoch 8
# Batch 20, Loss: 0.2620
# Batch 40, Loss: 0.2541
# Batch 60, Loss: 0.2643
# Epoch: 9 - Train Loss: 0.2508, Train Acc: 0.9368 | Val Loss: 0.2229, Val Acc: 0.9465
# Best model saved at epoch 9
# Batch 20, Loss: 0.2327
# Batch 40, Loss: 0.2435
# Batch 60, Loss: 0.2508
# Epoch: 10 - Train Loss: 0.2467, Train Acc: 0.9368 | Val Loss: 0.2119, Val Acc: 0.9512
# Best model saved at epoch 10
# Batch 20, Loss: 0.2067
# Batch 40, Loss: 0.2354
# Batch 60, Loss: 0.2005
# Epoch: 11 - Train Loss: 0.2455, Train Acc: 0.9368 | Val Loss: 0.2111, Val Acc: 0.9488
# Batch 20, Loss: 0.1928
# Batch 40, Loss: 0.2651
# Batch 60, Loss: 0.2437
# Epoch: 12 - Train Loss: 0.2336, Train Acc: 0.9432 | Val Loss: 0.2047, Val Acc: 0.9488
# Best model saved at epoch 12
# Batch 20, Loss: 0.1740
# Batch 40, Loss: 0.2259
# Batch 60, Loss: 0.1897
# Epoch: 13 - Train Loss: 0.2336, Train Acc: 0.9442 | Val Loss: 0.2090, Val Acc: 0.9558
# Batch 20, Loss: 0.1800
# Batch 40, Loss: 0.2351
# Batch 60, Loss: 0.2113
# Epoch: 14 - Train Loss: 0.2316, Train Acc: 0.9457 | Val Loss: 0.2025, Val Acc: 0.9558
# Best model saved at epoch 14
# Batch 20, Loss: 0.2306
# Batch 40, Loss: 0.2180
# Batch 60, Loss: 0.2489
# Epoch: 15 - Train Loss: 0.2255, Train Acc: 0.9502 | Val Loss: 0.1974, Val Acc: 0.9581
# Best model saved at epoch 15
# Batch 20, Loss: 0.1712
# Batch 40, Loss: 0.1891
# Batch 60, Loss: 0.1773
# Epoch: 16 - Train Loss: 0.2241, Train Acc: 0.9507 | Val Loss: 0.1957, Val Acc: 0.9651
# Best model saved at epoch 16
# Batch 20, Loss: 0.1997
# Batch 40, Loss: 0.1871
# Batch 60, Loss: 0.1806
# Epoch: 17 - Train Loss: 0.2250, Train Acc: 0.9482 | Val Loss: 0.1901, Val Acc: 0.9698
# Best model saved at epoch 17
# Batch 20, Loss: 0.2295
# Batch 40, Loss: 0.2076
# Batch 60, Loss: 0.2352
# Epoch: 18 - Train Loss: 0.2237, Train Acc: 0.9487 | Val Loss: 0.1933, Val Acc: 0.9651
# Batch 20, Loss: 0.1889
# Batch 40, Loss: 0.2290
# Batch 60, Loss: 0.1616
# Epoch: 19 - Train Loss: 0.2144, Train Acc: 0.9567 | Val Loss: 0.1881, Val Acc: 0.9628
# Best model saved at epoch 19
# Batch 20, Loss: 0.2058
# Batch 40, Loss: 0.1883
# Batch 60, Loss: 0.1957
# Epoch: 20 - Train Loss: 0.2197, Train Acc: 0.9537 | Val Loss: 0.1896, Val Acc: 0.9674
# Batch 20, Loss: 0.1840
# Batch 40, Loss: 0.2058
# Batch 60, Loss: 0.2075
# Epoch: 21 - Train Loss: 0.2145, Train Acc: 0.9567 | Val Loss: 0.1892, Val Acc: 0.9698
# Batch 20, Loss: 0.2328
# Batch 40, Loss: 0.2085
# Batch 60, Loss: 0.2016
# Epoch: 22 - Train Loss: 0.2109, Train Acc: 0.9572 | Val Loss: 0.1883, Val Acc: 0.9721
# Batch 20, Loss: 0.1741
# Batch 40, Loss: 0.2035
# Batch 60, Loss: 0.1571
# Epoch: 23 - Train Loss: 0.2121, Train Acc: 0.9572 | Val Loss: 0.1851, Val Acc: 0.9721
# Best model saved at epoch 23
# Batch 20, Loss: 0.1542
# Batch 40, Loss: 0.2740
# Batch 60, Loss: 0.2081
# Epoch: 24 - Train Loss: 0.2186, Train Acc: 0.9522 | Val Loss: 0.1818, Val Acc: 0.9721
# Best model saved at epoch 24
# Batch 20, Loss: 0.1749
# Batch 40, Loss: 0.1862
# Batch 60, Loss: 0.2412
# Epoch: 25 - Train Loss: 0.2112, Train Acc: 0.9557 | Val Loss: 0.1869, Val Acc: 0.9698
# Batch 20, Loss: 0.1671
# Batch 40, Loss: 0.2025
# Batch 60, Loss: 0.1874
# Epoch: 26 - Train Loss: 0.2054, Train Acc: 0.9612 | Val Loss: 0.1810, Val Acc: 0.9791
# Batch 20, Loss: 0.2754
# Batch 40, Loss: 0.1960
# Batch 60, Loss: 0.2266
# Epoch: 27 - Train Loss: 0.2084, Train Acc: 0.9552 | Val Loss: 0.1812, Val Acc: 0.9767
# Batch 20, Loss: 0.2019
# Batch 40, Loss: 0.1531
# Batch 60, Loss: 0.2197
# Epoch: 28 - Train Loss: 0.2065, Train Acc: 0.9562 | Val Loss: 0.1790, Val Acc: 0.9791
# Best model saved at epoch 28
# Batch 20, Loss: 0.1477
# Batch 40, Loss: 0.1971
# Batch 60, Loss: 0.2132
# Epoch: 29 - Train Loss: 0.2051, Train Acc: 0.9592 | Val Loss: 0.1797, Val Acc: 0.9744
# Batch 20, Loss: 0.2099
# Batch 40, Loss: 0.2541
# Batch 60, Loss: 0.1990
# Epoch: 30 - Train Loss: 0.2060, Train Acc: 0.9552 | Val Loss: 0.1804, Val Acc: 0.9791
# Batch 20, Loss: 0.1837
# Batch 40, Loss: 0.1835
# Batch 60, Loss: 0.1994
# Epoch: 31 - Train Loss: 0.2026, Train Acc: 0.9636 | Val Loss: 0.1788, Val Acc: 0.9744
# Batch 20, Loss: 0.1673
# Batch 40, Loss: 0.1716
# Batch 60, Loss: 0.1669
# Epoch: 32 - Train Loss: 0.2063, Train Acc: 0.9557 | Val Loss: 0.1762, Val Acc: 0.9767
# Best model saved at epoch 32
# Batch 20, Loss: 0.1869
# Batch 40, Loss: 0.1660
# Batch 60, Loss: 0.2385
# Epoch: 33 - Train Loss: 0.2020, Train Acc: 0.9622 | Val Loss: 0.1777, Val Acc: 0.9767
# Batch 20, Loss: 0.2031
# Batch 40, Loss: 0.1750
# Batch 60, Loss: 0.1667
# Epoch: 34 - Train Loss: 0.2072, Train Acc: 0.9597 | Val Loss: 0.1766, Val Acc: 0.9767
# Batch 20, Loss: 0.2326
# Batch 40, Loss: 0.1466
# Batch 60, Loss: 0.1788
# Epoch: 35 - Train Loss: 0.1979, Train Acc: 0.9641 | Val Loss: 0.1822, Val Acc: 0.9814
#
# Duration: 800 seconds
#
# ===== Final Average Results ======
#
# Train Accuracy (best val loss): 0.9572 +- 0.0011
# Valid Accuracy: 0.9736 +- 0.0029
# Train Loss: 0.2078 +- 0.0034
# Valid Loss: 0.1784 +- 0.0053
# n\Best overall model was from run 1 with val loss 0.1733
# Saved as: base_simclr_new_extension/best_simclr_extension_overall.pth

# %%
# save full simCLR model 
torch.save(encoder.state_dict(), os.path.join(save_dir_simclr_extension, 'best_simclr_encoder_only.pth'))

# %%
model = LinearClassifier(encoder = encoder, feature_dim=512, num_classes=2).to(device)

# %%
model_dir_extension = os.path.join(PROJECT_ROOT, 'base_simclr_new_extension')
model_filename_extension = 'best_simclr_extension_overall.pth'
model_path_extension = os.path.join(model_dir_extension, model_filename_extension)

# %%
model.load_state_dict(torch.load(model_path_extension))
model  = model.to(device)
model.eval()
# Out:
# LinearClassifier(
#   (encoder): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#     (fc): Identity()
#   )
#   (classifier): Linear(in_features=512, out_features=2, bias=True)
# )

# %%
import seaborn as sns
model.eval()
all_preds = []
all_labels = []
with torch.no_grad():
    for images, labels in valid_loader:
        images = images.to('cuda')
        labels = labels.to('cuda')

        outputs = model(images)
        _, preds = torch.max(outputs,1)

        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

# %%
print("classification_report:\n")
print(classification_report(all_labels, all_preds))
# Out:
# classification_report:
#
#               precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91        59
#            1       0.99      0.98      0.99       371
#
#     accuracy                           0.97       430
#    macro avg       0.94      0.96      0.95       430
# weighted avg       0.98      0.97      0.97       430

# %%
# confusion matrix
# visulize train and valid loss
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(all_labels, all_preds)
plt.figure(figsize=(6,4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Non-Tumor', 'Tumor'],
            yticklabels=['Non-Tumor','Tumor'])
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('')
plt.tight_layout()
plt.show()

# %%
max_len = max(len(run) for run in train_accuracies_all)

# %%
def pad_to_max(arr_list, max_len):
    return np.array([np.pad(run, (0, max_len - len(run)), constant_values=np.nan) for run in arr_list])

train_accuracies_pad = pad_to_max(train_accuracies_all, max_len)
valid_accuracies_pad = pad_to_max(valid_accuracies_all, max_len)
train_losses_pad = pad_to_max(train_losses_all, max_len)
valid_losses_pad = pad_to_max(valid_losses_all, max_len)

# %%
epochs = list(range(1, max_len + 1))
mean_train_acc = np.nanmean(train_accuracies_pad, axis=0)
std_train_acc = np.nanstd(train_accuracies_pad, axis=0)

mean_valid_acc = np.nanmean(valid_accuracies_pad, axis=0)
std_valid_acc = np.nanstd(valid_accuracies_pad, axis=0)


plt.figure(figsize = (8,5))
plt.plot(epochs, mean_train_acc, label='Train Accuracy', color = 'blue')
plt.fill_between(epochs, mean_train_acc - std_train_acc, mean_train_acc + std_train_acc, alpha = 0.1, color = 'blue')

plt.plot(epochs, mean_valid_acc, label='Valid Accuracy', color = 'orange')
plt.fill_between(epochs, mean_valid_acc - std_valid_acc, mean_valid_acc + std_valid_acc, alpha = 0.1, color = 'orange')

plt.title('')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
def pad_to_max(loss_list, max_len):
    return np.array([np.pad(run, (0, max_len - len(run)), constant_values=np.nan) for run in loss_list])


train_losses_pad = pad_to_max(train_losses_all, max_len)
valid_losses_pad = pad_to_max(valid_losses_all, max_len)

# %%
epochs = list(range(1, max_len + 1))
mean_train_loss = np.nanmean(train_losses_pad, axis=0)
std_train_loss = np.nanstd(train_losses_pad, axis=0)

mean_valid_loss = np.nanmean(valid_losses_pad, axis=0)
std_valid_loss = np.nanstd(valid_losses_pad,axis=0)

epochs = list(range(1, len(mean_train_loss)+1))

plt.figure(figsize = (8,5))
plt.plot(epochs, mean_train_loss, label='Train Loss', color = 'blue')
plt.fill_between(epochs, mean_train_loss - std_train_loss, mean_train_loss + std_train_loss, alpha = 0.1, color = 'blue')

plt.plot(epochs, mean_valid_loss, label='Valid Loss', color = 'orange')
plt.fill_between(epochs, mean_valid_loss - std_valid_loss, mean_valid_loss + std_valid_loss, alpha = 0.1, color = 'orange')

plt.title('')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
